# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
parquet_file = '../files/parquet/homelike_assignment_data.parquet'
df = pd.read_parquet(parquet_file)

# %%
print("The shape of the DF: ", df.shape)
print("The types of the DF: ")
df.dtypes
# Out:
# The shape of the DF:  (776736, 8)
# The types of the DF:
# ts              object
# event_type      object
# session_id      object
# user_country    object
# user_agent      object
# page_country    object
# env             object
# params          object
# dtype: object

# %% [markdown]
# ## At first we can notice that all the columns are of type object and they should be coverted for further analysis

# %%
for col in df.columns:
    null_count = df[col].isnull().sum()
    percentage = format(null_count/df.shape[0], '.10f')
    print(f'''The null values of column {"'"+col+"'"} are {str(null_count)} and the percentage in the whole DF {str(percentage)}''')
# Out:
# The null values of column 'ts' are 72 and the percentage in the whole DF 0.0000926956
# The null values of column 'event_type' are 80 and the percentage in the whole DF 0.0001029951
# The null values of column 'session_id' are 83 and the percentage in the whole DF 0.0001068574
# The null values of column 'user_country' are 79 and the percentage in the whole DF 0.0001017077
# The null values of column 'user_agent' are 83 and the percentage in the whole DF 0.0001068574
# The null values of column 'page_country' are 75 and the percentage in the whole DF 0.0000965579
# The null values of column 'env' are 65 and the percentage in the whole DF 0.0000836835
# The null values of column 'params' are 712497 and the percentage in the whole DF 0.9172962242

# %% [markdown]
# #### - Furthermore from a quick check we can notice on 7 of the 8 columns that some null values exist but exist in small percentange.
# #### - On params column the percentage in null values in the whole dataset is 91,71 % is very high
# #### - In both cases we need further investigation firstly how these null values are created and secondly if we can fix them somehow.
# #### - For sure we should not have any null values in timestamp column

# %% [markdown]
# ### Check unique values in some columns as well as a preview of the none values in each column

# %%
df[df.ts.isnull()].head()
# Out:
#          ts           event_type        session_id user_country  \
# 10956  None  image_gallery_swipe  sgffe8oncipm4142           FR
# 12393  None       apartment_view  gxqdmf72o432ykhr           IT
# 38936  None             map_zoom  mmnxe1ksu3bn5y1w           PT
# 55767  None             map_zoom  fy25cw2ce21qgych           CH
# 85262  None  image_gallery_swipe  6wvozsxctn9ntiz9           DE
#
#                                               user_agent page_country  \
# 10956  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1...           FR
# 12393  Mozilla/4.0 (compatible; MSIE 7.0; connectpro;...           FR
# 38936  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           DE
# 55767  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           FR
# 85262  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           FR
#
#               env                                             params
# 10956  production                                               None
# 12393  production  {'apartment': 'pa2egkcfprjxp15a', 'apartments'...
# 38936  production                                               None
# 55767  production                                               None
# 85262  production                                               None

# %%
print(df.event_type.unique())

df[df.event_type.isnull()].head()
# Out:
# ['image_gallery_swipe' 'map_zoom' 'map_move' 'apartment_view' 'page_view'
#  'search_impression' 'create_request' 'paid_request' None]
#                         ts event_type        session_id user_country  \
# 15053  2025-03-01T08:49:33       None  9g6ilwwftiao67ma           IT
# 16107  2025-03-01T03:29:41       None  utod4znglmh6ax1x           DE
# 34418  2025-03-01T01:48:31       None  oz1dtk2th4czn9r2           PT
# 34892  2025-03-01T00:16:11       None  thxqa6da33dexc0u           FR
# 64962  2025-03-01T06:05:42       None  8m7x9aouxfkm7y5a           DE
#
#                                               user_agent page_country  \
# 15053  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           ES
# 16107  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...           ES
# 34418  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)...           DE
# 34892  Opera/9.80 (X11;Linux armv7i;NETRANGEMMH;HbbTV...           ES
# 64962  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...           FR
#
#               env                                             params
# 15053  production                                               None
# 16107  production  {'apartment': 'uc5zq1bhyck22jy6', 'apartments'...
# 34418  production                                               None
# 34892  production                                               None
# 64962  production                                               None

# %%
df[df.session_id.isnull()].head()
# Out:
#                         ts           event_type session_id user_country  \
# 6367   2025-03-01T04:44:35  image_gallery_swipe       None           BE
# 10041  2025-03-01T06:38:35    search_impression       None           BE
# 11659  2025-03-01T09:40:39             map_zoom       None           ES
# 12735  2025-03-01T08:03:50  image_gallery_swipe       None           IT
# 26212  2025-03-01T06:24:07             map_move       None           PT
#
#                                               user_agent page_country  \
# 6367   Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...           ES
# 10041  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...           FR
# 11659  Opera/9.80 (J2ME/MIDP; Opera Mini/4.2.18149/37...           FR
# 12735  Mozilla/5.0 (Linux; Android 4.4.2; SM-T230 Bui...           ES
# 26212  Mozilla/5.0 (Linux; U; Android 4.3; en-in; ASU...           DE
#
#               env                                             params
# 6367   production                                               None
# 10041  production  {'apartment': None, 'apartments': ['53ygw9e4rp...
# 11659  production                                               None
# 12735  production                                               None
# 26212  production                                               None

# %%
print(df.user_country.unique())

df[df.user_country.isnull()].head()
# Out:
# ['BE' 'US' 'PT' 'NL' 'FR' 'DE' 'CH' 'ES' 'IT' None]
#                         ts           event_type        session_id  \
# 18188  2025-03-01T03:38:23  image_gallery_swipe  ub3syr9jecqbyq7h
# 26280  2025-03-01T05:33:56             map_zoom  o5f4hdrami1zpzr3
# 30978  2025-03-01T08:28:45             map_zoom  rlr2wzpdeeqmxzbs
# 49588  2025-03-01T08:43:55             map_move  ulqlnu8tfep7kgia
# 50416  2025-03-01T06:12:18             map_zoom  9d9itjz8pft06mwk
#
#       user_country                                         user_agent  \
# 18188         None  Opera/9.80 (J2ME/MIDP; Opera Mini/4.5.40380/65...
# 26280         None  Mozilla/5.0 (Linux; Android 5.1; Hudl 2 Build/...
# 30978         None  Mozilla/5.0 (Linux; Android 6.0.1; LG-K520 Bui...
# 49588         None  Mozilla/5.0 (Linux; Android 7.0; Moto G (4) Bu...
# 50416         None  Mozilla/5.0 (Linux; Android 4.4.2; SAMSUNG-SGH...
#
#       page_country         env params
# 18188           DE  production   None
# 26280           ES  production   None
# 30978           ES  production   None
# 49588           FR  production   None
# 50416           FR  production   None

# %%
print(df['user_agent'][3])

df[df.user_agent.isnull()].head()
# Out:
# Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US; rv:1.9.1.7) Gecko/20091221 Firefox/3.5.7 (.NET CLR 3.5.30729) FBSMTWB
#                         ts           event_type        session_id  \
# 6655   2025-03-01T04:17:21  image_gallery_swipe  03c0bvl67wi0uh4o
# 10462  2025-03-01T08:53:26       apartment_view  wm66thrmcoytokcb
# 20136  2025-03-01T09:00:16  image_gallery_swipe  jrgbn37naarh3vcb
# 41804  2025-03-01T02:08:23  image_gallery_swipe  gz2ce9semmbdskbc
# 44921  2025-03-01T07:12:44  image_gallery_swipe  fk2vebz7ws4wh5lh
#
#       user_country user_agent page_country         env  \
# 6655            CH       None           ES  production
# 10462           BE       None           DE  production
# 20136           IT       None           ES  production
# 41804           IT       None           FR  production
# 44921           CH       None           FR  production
#
#                                                   params
# 6655                                                None
# 10462  {'apartment': 'tl0gmpxbe7pjpwoa', 'apartments'...
# 20136                                               None
# 41804                                               None
# 44921                                               None

# %%
print(df.page_country.unique())

df[df.page_country.isnull()].head() # there is timestamp in different format
# Out:
# ['DE' 'FR' 'ES' None]
#                         ts event_type        session_id user_country  \
# 55364  2025-03-01T02:23:47   map_move  wz8ue1eyyyc0lo98           ES
# 77676  2025-03-01T06:03:31   map_zoom  w37gjp9ykr3qimdr           CH
# 83561         1740788102.0   map_move  kmq8jibgfni41hoi           BE
# 86763  2025-03-01T09:03:15   map_zoom  5xz7l7skla89943u           BE
# 91034  2025-03-01T08:01:54   map_move  fj06hwoq51psidp4           NL
#
#                                               user_agent page_country  \
# 55364  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...         None
# 77676  Mozilla/5.0 (Linux; U; Android 6.0.1; en-US; S...         None
# 83561  Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US...         None
# 86763  Mozilla/5.0 (iPhone; CPU iPhone OS 11_0_1 like...         None
# 91034  Mozilla/5.0 (Linux; Android 4.4.4; HM NOTE 1S ...         None
#
#               env params
# 55364  production   None
# 77676  production   None
# 83561  production   None
# 86763  production   None
# 91034  production   None

# %%
print(df.env.unique())

df[df.env.isnull()].head()
# Out:
# ['production' 'staging' None]
#                         ts           event_type        session_id  \
# 5820   2025-03-01T00:38:26             map_zoom  8xkd5baum6t3uy4w
# 30159  2025-03-01T06:32:06  image_gallery_swipe  ho6c57pa7f2sa7c5
# 54646  2025-03-01T07:33:08  image_gallery_swipe  5d7whgcyphdxg2p5
# 83570  2025-03-01T05:23:38       apartment_view  mdm42525nz0kqyge
# 96807  2025-03-01T05:07:08  image_gallery_swipe  6hk5np3pxvk63r5n
#
#       user_country                                         user_agent  \
# 5820            US  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 30159           BE  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# 54646           FR  Opera/9.80 (MAUI Runtime; Opera Mini/4.4.31998...
# 83570           CH  Opera/9.80 (Android; Opera Mini/15.0.2125/107....
# 96807           US  Mozilla/5.0 (compatible; MSIE 11.0; Windows NT...
#
#       page_country   env                                             params
# 5820            DE  None                                               None
# 30159           DE  None                                               None
# 54646           ES  None                                               None
# 83570           ES  None  {'apartment': 'uwuu97q672zqy4t4', 'apartments'...
# 96807           ES  None                                               None

# %%
df[df.params.notnull()].head()
# Out:
#                      ts         event_type        session_id user_country  \
# 18  2025-03-01T06:52:38     apartment_view  5a3aiqtknbe4ysq5           BE
# 22  2025-03-01T06:38:06     apartment_view  mgiqv4bg4urss1he           US
# 24  2025-03-01T04:16:23          page_view  27oquq2hw5z896gh           US
# 35  2025-03-01T04:50:53     apartment_view  j6zuln4d7r4y22an           IT
# 38  2025-03-01T07:41:35  search_impression  1a67h8odbog61z9g           US
#
#                                            user_agent page_country  \
# 18  UCWEB/2.0 (MIDP-2.0; U; Adr 4.1.2; id; GT-S528...           DE
# 22  Opera/9.80 (Android; Opera Mini/8.0.1807/95.90...           DE
# 24  Mozilla/5.0 (Linux; Android 4.2.2; SNB02-NV7A ...           ES
# 35  Mozilla/5.0 (Linux; Android 5.1.1; A0001 Build...           DE
# 38  Mozilla/5.0 (iPad; CPU OS 10_3_3 like Mac OS X...           ES
#
#            env                                             params
# 18  production  {'apartment': '4xo274ju8xiform5', 'apartments'...
# 22  production  {'apartment': 'g0844e1q5yw1dejm', 'apartments'...
# 24  production  {'apartment': None, 'apartments': None, 'page'...
# 35  production  {'apartment': 'ybkbawv8x9cpwym1', 'apartments'...
# 38  production  {'apartment': None, 'apartments': ['uc5zq1bhyc...

# %%
# Print some examples
print(df['params'][12393])
print(df['params'][18])
print(df['params'][22])
# Out:
# {'apartment': 'pa2egkcfprjxp15a', 'apartments': None, 'page': None, 'request': None}
# {'apartment': '4xo274ju8xiform5', 'apartments': None, 'page': None, 'request': None}
# {'apartment': 'g0844e1q5yw1dejm', 'apartments': None, 'page': None, 'request': None}

# %% [markdown]
# #### We can notice also that in params column there are dictionaries in cells, i guess this must be brought in the same format to the table

# %%
def extract_values(row):
    return pd.Series(row['params'])

# %%
df[['apartment', 'apartments', 'page', 'requests']] = df.apply(extract_values, axis=1)

# %%
# Now the columns are created 
df.loc[12393]
# Out:
# ts                                                           None
# event_type                                         apartment_view
# session_id                                       gxqdmf72o432ykhr
# user_country                                                   IT
# user_agent      Mozilla/4.0 (compatible; MSIE 7.0; connectpro;...
# page_country                                                   FR
# env                                                    production
# params          {'apartment': 'pa2egkcfprjxp15a', 'apartments'...
# Name: 12393, dtype: object

# %%
print(df.shape[0])
print(df['session_id'].value_counts())
# Out:
# 776736
# session_id
# k7ov0g5jp9l66rio    106
# lnosko96z4gl0dou    104
# 7z8pwz2kpnbjeihz    104
# qgeh99kfb2uuqzn7    103
# fuzhyuv7wloth31e    103
#                    ...
# 0burybc63x74nuy2      1
# d9dbjrfoiarc8qt9      1
# nr0wpzsxdnfvjetf      1
# zgx556598h3boj4c      1
# m19v4ymaevtyi63v      1
# Name: count, Length: 10452, dtype: int64

# %%
# A lot of timestamps have a different format
df['ts'].value_counts().tail(50)
# Out:
# ts
# 03/01/2025, 07:03:19    1
# 03/01/2025, 09:52:35    1
# 1740791175.0            1
# 03/01/2025, 00:59:01    1
# 1740799728.0            1
# 1740792620.0            1
# 03/01/2025, 06:02:21    1
# 1740806605.0            1
# 03/01/2025, 05:14:48    1
# 1740802079.0            1
# 1740820026.0            1
# 1740799678.0            1
# 2025-03-01T10:09:52     1
# 1740801154.0            1
# 1740808401.0            1
# 1740802588.0            1
# 03/01/2025, 02:17:29    1
# 1740801937.0            1
# 03/01/2025, 01:31:27    1
# 03/01/2025, 06:07:23    1
# 03/01/2025, 08:51:00    1
# 1740804204.0            1
# 03/01/2025, 07:36:09    1
# 1740820659.0            1
# 1740813961.0            1
# 03/01/2025, 07:05:13    1
# 1740794854.0            1
# 1740792708.0            1
# 1740788510.0            1
# 1740791397.0            1
# 1740799275.0            1
# 03/01/2025, 05:38:42    1
# 03/01/2025, 07:57:42    1
# 03/01/2025, 02:37:59    1
# 03/01/2025, 00:50:26    1
# 1740792785.0            1
# 03/01/2025, 00:21:49    1
# 1740817745.0            1
# 03/01/2025, 03:00:01    1
# 03/01/2025, 08:49:23    1
# 03/01/2025, 02:41:49    1
# 03/01/2025, 08:50:02    1
# 03/01/2025, 07:19:36    1
# 1740814493.0            1
# 03/01/2025, 07:37:02    1
# 1740820276.0            1
# 1740803017.0            1
# 1740788279.0            1
# 1740809239.0            1
# 1740823405.0            1
# Name: count, dtype: int64

# %%
df['ts'] = df['ts'].apply(lambda x: str(x) if pd.notnull(x) else '')

# %%
# we have ts that contain '/' also ts that have totaly different format
df[df['ts'].str.contains('-')]
# Out:
#                          ts           event_type        session_id  \
# 0       2025-03-01T08:39:52  image_gallery_swipe  x4m59xw01v7x1o3x
# 1       2025-03-01T01:42:30             map_zoom  lblh6b3b8c1313h4
# 2       2025-03-01T10:03:08  image_gallery_swipe  fzhih6yuth0z3z43
# 3       2025-03-01T01:43:02  image_gallery_swipe  gixdutwq49v0axsp
# 4       2025-03-01T06:37:54  image_gallery_swipe  tml3qec164y1myh5
# ...                     ...                  ...               ...
# 776731  2025-03-01T06:02:17             map_move  vjqkchm10thc4j1r
# 776732  2025-03-01T06:13:46  image_gallery_swipe  1iny7mnyr4ae1knu
# 776733  2025-03-01T09:42:49             map_zoom  didr8c403tug8a7s
# 776734  2025-03-01T07:16:28             map_zoom  7s7uy0x5wbz1xm2r
# 776735  2025-03-01T00:37:35             map_zoom  j340wrs19us6us8h
#
#        user_country                                         user_agent  \
# 0                BE  Mozilla/5.0 (Linux; Android 7.0; SM-G955U Buil...
# 1                US  Mozilla/5.0 (Windows NT 6.0; Win64; x64) Apple...
# 2                PT  Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:48...
# 3                US  Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US...
# 4                NL  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# ...             ...                                                ...
# 776731           ES  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 776732           PT  Mozilla/5.0 (Linux; Android 7.1.2; Redmi 4A Bu...
# 776733           IT  Opera/9.80 (iPhone; Opera Mini/7.0.2/27.1993; ...
# 776734           DE  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 776735           DE  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_4 like ...
#
#        page_country         env params
# 0                DE  production   None
# 1                FR  production   None
# 2                DE  production   None
# 3                FR  production   None
# 4                DE  production   None
# ...             ...         ...    ...
# 776731           FR  production   None
# 776732           FR  production   None
# 776733           DE  production   None
# 776734           FR  production   None
# 776735           FR  production   None
#
# [766659 rows x 8 columns]

# %%
def fix_dates1(x):
    '''Fuction that fix timestamps from '%Y-%m-%dT%H:%M:%S' to 'dd/mm/yyyy HH:MM:SS' format.'''
    try:
        dt_object = datetime.strptime(x, '%Y-%m-%dT%H:%M:%S')
        formatted_timestamp = str(dt_object.strftime('%d/%m/%Y %H:%M:%S'))

        return formatted_timestamp
    except Exception as e:
        print(f"Error while converting ts from '%Y-%m-%dT%H:%M:%S' to 'dd/mm/yyyy HH:MM:SS' format: {e}")
        return np.nan

# %%
df['ts'] = df['ts'].apply(lambda x: fix_dates1(x) if '-' in x else x)

# %%
#Check again 
errors = df[~df.ts.str.contains('/')]

# %%
errors['ts'][10956] == ''
# Out:
# True

# %%
errors[~errors.ts.str.contains('.')]
# Out:
#        ts           event_type        session_id user_country  \
# 10956      image_gallery_swipe  sgffe8oncipm4142           FR
# 12393           apartment_view  gxqdmf72o432ykhr           IT
# 38936                 map_zoom  mmnxe1ksu3bn5y1w           PT
# 55767                 map_zoom  fy25cw2ce21qgych           CH
# 85262      image_gallery_swipe  6wvozsxctn9ntiz9           DE
# ...    ..                  ...               ...          ...
# 713863     image_gallery_swipe  1f505xtecpyva3ko           ES
# 725573     image_gallery_swipe  zr27ps2qbun75sjf           DE
# 726420     image_gallery_swipe  zalsfspienuaw28s           FR
# 759645     image_gallery_swipe  dr5bd9sawpaf8yvi           PT
# 773772     image_gallery_swipe  dk00yu9vjdfsdl4f           FR
#
#                                                user_agent page_country  \
# 10956   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1...           FR
# 12393   Mozilla/4.0 (compatible; MSIE 7.0; connectpro;...           FR
# 38936   Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           DE
# 55767   Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           FR
# 85262   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           FR
# ...                                                   ...          ...
# 713863  Mozilla/5.0 (MSIE 9.0; qdesk 2.5.1277.202; Win...           DE
# 725573  Opera/9.80 (Series 60; Opera Mini/7.1.32444/37...           DE
# 726420  Mozilla/5.0 (Linux; Android 5.1; vivo Y21 Buil...           DE
# 759645  Mozilla/5.0 (Linux; Android 5.1; XT1052 Build/...           ES
# 773772  Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; T...           DE
#
#                env                                             params
# 10956   production                                               None
# 12393   production  {'apartment': 'pa2egkcfprjxp15a', 'apartments'...
# 38936   production                                               None
# 55767   production                                               None
# 85262   production                                               None
# ...            ...                                                ...
# 713863  production                                               None
# 725573  production                                               None
# 726420  production                                               None
# 759645  production                                               None
# 773772  production                                               None
#
# [72 rows x 8 columns]

# %%
def fix_dates2(x):
    '''Fuction that fix timestamps from floats to 'dd/mm/yyyy HH:MM:SS' format.'''
    try:
        dt_object = datetime.utcfromtimestamp(float(x))
        formatted_timestamp = str(dt_object.strftime('%d/%m/%Y %H:%M:%S'))

        return formatted_timestamp
    except Exception as e:
        print(f"Error while converting ts from floats to 'dd/mm/yyyy HH:MM:SS' format: {e}")
        return np.nan

# %%
df['ts'] = df['ts'].apply(lambda x: fix_dates2(x) if ('/' not in x and x != '') else x)

# %%
# Check again
df[~df.ts.str.contains('/')]
# Out:
#        ts           event_type        session_id user_country  \
# 10956      image_gallery_swipe  sgffe8oncipm4142           FR
# 12393           apartment_view  gxqdmf72o432ykhr           IT
# 38936                 map_zoom  mmnxe1ksu3bn5y1w           PT
# 55767                 map_zoom  fy25cw2ce21qgych           CH
# 85262      image_gallery_swipe  6wvozsxctn9ntiz9           DE
# ...    ..                  ...               ...          ...
# 713863     image_gallery_swipe  1f505xtecpyva3ko           ES
# 725573     image_gallery_swipe  zr27ps2qbun75sjf           DE
# 726420     image_gallery_swipe  zalsfspienuaw28s           FR
# 759645     image_gallery_swipe  dr5bd9sawpaf8yvi           PT
# 773772     image_gallery_swipe  dk00yu9vjdfsdl4f           FR
#
#                                                user_agent page_country  \
# 10956   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1...           FR
# 12393   Mozilla/4.0 (compatible; MSIE 7.0; connectpro;...           FR
# 38936   Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           DE
# 55767   Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...           FR
# 85262   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...           FR
# ...                                                   ...          ...
# 713863  Mozilla/5.0 (MSIE 9.0; qdesk 2.5.1277.202; Win...           DE
# 725573  Opera/9.80 (Series 60; Opera Mini/7.1.32444/37...           DE
# 726420  Mozilla/5.0 (Linux; Android 5.1; vivo Y21 Buil...           DE
# 759645  Mozilla/5.0 (Linux; Android 5.1; XT1052 Build/...           ES
# 773772  Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; T...           DE
#
#                env                                             params
# 10956   production                                               None
# 12393   production  {'apartment': 'pa2egkcfprjxp15a', 'apartments'...
# 38936   production                                               None
# 55767   production                                               None
# 85262   production                                               None
# ...            ...                                                ...
# 713863  production                                               None
# 725573  production                                               None
# 726420  production                                               None
# 759645  production                                               None
# 773772  production                                               None
#
# [72 rows x 8 columns]

# %%
df.loc[10953:10958]
# Out:
#                         ts           event_type        session_id  \
# 10953  01/03/2025 09:38:29  image_gallery_swipe  qxlk6hxezulk9cbg
# 10954  01/03/2025 00:09:15  image_gallery_swipe  h9naskbwocqpk9xq
# 10955  01/03/2025 02:18:19  image_gallery_swipe  7e2wl4qy36ykpbd0
# 10956                       image_gallery_swipe  sgffe8oncipm4142
# 10957  01/03/2025 01:13:17  image_gallery_swipe  6qynu0cs774o9vb9
# 10958  01/03/2025 03:14:01  image_gallery_swipe  ppzfmplrsap64yr8
#
#       user_country                                         user_agent  \
# 10953           ES  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 10954           DE  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 10955           DE  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 10956           FR  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1...
# 10957           ES  Opera/9.80 (J2ME/MIDP; Opera Mini/4.5.40312/66...
# 10958           PT  Mozilla/5.0 (Windows NT 6.3) AppleWebKit/537.3...
#
#       page_country         env params
# 10953           FR  production   None
# 10954           DE  production   None
# 10955           ES  production   None
# 10956           FR  production   None
# 10957           DE  production   None
# 10958           ES  production   None

# %% [markdown]
# #### I cannot see a pattern in the timestamps in order to fill the empty cells with interpolation so i will drop the 72 rows.

# %%
df.shape
# Out:
# (776736, 8)

# %%
df = df[df.ts != '']

# %%
df.shape
# Out:
# (776664, 8)

# %% [markdown]
# #### Replace None values in specific columns with Unknown

# %%
def replace_none_with_unknown(x):
    '''Function that replaces empty values with 'Uknown' value.'''
    try:
        if not x:
            return 'Unknown'
        else:
            return x
    except Exception as e:
        print(f"Error while replacing None values with Unknown {e}")
        return np.nan

# %%
df['event_type'] = df['event_type'].apply(lambda x: replace_none_with_unknown(x))
df['user_country'] = df['user_country'].apply(lambda x: replace_none_with_unknown(x))
df['user_agent'] = df['user_agent'].apply(lambda x: replace_none_with_unknown(x))
df['page_country'] = df['page_country'].apply(lambda x: replace_none_with_unknown(x))
df['env'] = df['env'].apply(lambda x: replace_none_with_unknown(x))

# %%
df.drop('params', axis=1, inplace=True)

# %%
for col in df.columns:
    null_count = df[col].isnull().sum()
    percentage = format(null_count/df.shape[0], '.10f')
    print(f'''The null values of column {"'"+col+"'"} are {str(null_count)} and the percentage in the whole DF {str(percentage)}''')
# Out:
# The null values of column 'ts' are 0 and the percentage in the whole DF 0.0000000000
# The null values of column 'event_type' are 0 and the percentage in the whole DF 0.0000000000
# The null values of column 'session_id' are 83 and the percentage in the whole DF 0.0001068673
# The null values of column 'user_country' are 0 and the percentage in the whole DF 0.0000000000
# The null values of column 'user_agent' are 0 and the percentage in the whole DF 0.0000000000
# The null values of column 'page_country' are 0 and the percentage in the whole DF 0.0000000000
# The null values of column 'env' are 0 and the percentage in the whole DF 0.0000000000

# %%
df[df.session_id.isnull()]['user_agent'][10041]
# Out:
# 'UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532G) U2/1.0.0 UCBrowser/10.6.8.732 U2/1.0.0 Mobile'

# %%
df[df.user_agent == 'Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firefox/8.0'].head(25)
# Out:
#                          ts           event_type        session_id  \
# 6367    01/03/2025 04:44:35  image_gallery_swipe              None
# 16670   01/03/2025 04:44:04  image_gallery_swipe  viza0aq49zkk62i0
# 31802   01/03/2025 04:44:06  image_gallery_swipe  viza0aq49zkk62i0
# 32495   01/03/2025 04:45:47             map_zoom  viza0aq49zkk62i0
# 39667   01/03/2025 04:47:00  image_gallery_swipe  viza0aq49zkk62i0
# 39695   01/03/2025 04:45:05  image_gallery_swipe  viza0aq49zkk62i0
# 68535   01/03/2025 04:43:22  image_gallery_swipe  viza0aq49zkk62i0
# 76551   01/03/2025 04:44:37             map_zoom  viza0aq49zkk62i0
# 84174   01/03/2025 04:41:20  image_gallery_swipe  viza0aq49zkk62i0
# 95475   01/03/2025 04:44:29       apartment_view  viza0aq49zkk62i0
# 103935  01/03/2025 04:41:45             map_zoom  viza0aq49zkk62i0
# 115914  01/03/2025 04:42:52             map_zoom  viza0aq49zkk62i0
# 119180  01/03/2025 04:41:33             map_zoom  viza0aq49zkk62i0
# 119727  01/03/2025 04:43:08             map_move  viza0aq49zkk62i0
# 125101  01/03/2025 04:41:08  image_gallery_swipe  viza0aq49zkk62i0
# 125137  01/03/2025 04:40:26             map_zoom  viza0aq49zkk62i0
# 171900  01/03/2025 04:44:18             map_zoom  viza0aq49zkk62i0
# 176608  01/03/2025 04:43:17  image_gallery_swipe  viza0aq49zkk62i0
# 177160  01/03/2025 04:43:31             map_zoom  viza0aq49zkk62i0
# 185298  01/03/2025 04:41:57  image_gallery_swipe  viza0aq49zkk62i0
# 189778  01/03/2025 04:44:40             map_zoom  viza0aq49zkk62i0
# 191019  01/03/2025 04:45:51  image_gallery_swipe  viza0aq49zkk62i0
# 200831  01/03/2025 04:44:05             map_zoom  viza0aq49zkk62i0
# 206034  01/03/2025 04:41:02             map_zoom  viza0aq49zkk62i0
# 216142  01/03/2025 04:43:23             map_zoom  viza0aq49zkk62i0
#
#        user_country                                         user_agent  \
# 6367             BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 16670            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 31802            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 32495            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 39667            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 39695            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 68535            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 76551            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 84174            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 95475            BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 103935           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 115914           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 119180           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 119727           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 125101           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 125137           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 171900           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 176608           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 177160           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 185298           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 189778           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 191019           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 200831           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 206034           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
# 216142           BE  Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...
#
#        page_country         env
# 6367             ES  production
# 16670            ES  production
# 31802            ES  production
# 32495            ES  production
# 39667            ES  production
# 39695            ES  production
# 68535            ES  production
# 76551            ES  production
# 84174            ES  production
# 95475            ES  production
# 103935           ES  production
# 115914           ES  production
# 119180           ES  production
# 119727           ES  production
# 125101           ES  production
# 125137           ES  production
# 171900           ES  production
# 176608           ES  production
# 177160           ES  production
# 185298           ES  production
# 189778           ES  production
# 191019           ES  production
# 200831           ES  production
# 206034           ES  production
# 216142           ES  production

# %%
df[df.user_agent == 'UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532G) U2/1.0.0 UCBrowser/10.6.8.732 U2/1.0.0 Mobile'].head(25)
# Out:
#                          ts           event_type        session_id  \
# 5609    01/03/2025 06:39:43             map_move  e8ou3xn663r8gmwu
# 10041   01/03/2025 06:38:35    search_impression              None
# 16354   01/03/2025 06:48:21  image_gallery_swipe  e8ou3xn663r8gmwu
# 29507   01/03/2025 06:43:14             map_zoom  e8ou3xn663r8gmwu
# 43070   01/03/2025 06:42:39  image_gallery_swipe  e8ou3xn663r8gmwu
# 47525   01/03/2025 06:43:46  image_gallery_swipe  e8ou3xn663r8gmwu
# 56156   01/03/2025 06:48:24  image_gallery_swipe  e8ou3xn663r8gmwu
# 82894   01/03/2025 06:40:30  image_gallery_swipe  e8ou3xn663r8gmwu
# 86344   01/03/2025 06:49:16             map_move  e8ou3xn663r8gmwu
# 109694  01/03/2025 06:47:19       apartment_view  e8ou3xn663r8gmwu
# 111808  01/03/2025 06:46:06  image_gallery_swipe  e8ou3xn663r8gmwu
# 116294  01/03/2025 06:46:57             map_zoom  e8ou3xn663r8gmwu
# 129746  01/03/2025 06:45:42             map_zoom  e8ou3xn663r8gmwu
# 138887  01/03/2025 06:47:50  image_gallery_swipe  e8ou3xn663r8gmwu
# 154676  01/03/2025 06:45:05             map_move  e8ou3xn663r8gmwu
# 156754  01/03/2025 06:42:09             map_zoom  e8ou3xn663r8gmwu
# 163074  01/03/2025 06:40:57  image_gallery_swipe  e8ou3xn663r8gmwu
# 166168  01/03/2025 06:45:30             map_zoom  e8ou3xn663r8gmwu
# 180833  01/03/2025 06:45:52  image_gallery_swipe  e8ou3xn663r8gmwu
# 191602  01/03/2025 06:42:51             map_zoom  e8ou3xn663r8gmwu
# 209461  01/03/2025 06:40:37             map_move  e8ou3xn663r8gmwu
# 211390  01/03/2025 06:49:02             map_zoom  e8ou3xn663r8gmwu
# 212661  01/03/2025 06:44:38  image_gallery_swipe  e8ou3xn663r8gmwu
# 231084  01/03/2025 06:47:33             map_move  e8ou3xn663r8gmwu
# 240273  01/03/2025 06:43:40  image_gallery_swipe  e8ou3xn663r8gmwu
#
#        user_country                                         user_agent  \
# 5609             BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 10041            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 16354            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 29507            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 43070            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 47525            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 56156            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 82894            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 86344            BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 109694           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 111808           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 116294           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 129746           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 138887           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 154676           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 156754           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 163074           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 166168           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 180833           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 191602           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 209461           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 211390           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 212661           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 231084           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
# 240273           BE  UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...
#
#        page_country         env
# 5609             FR  production
# 10041            FR  production
# 16354            FR  production
# 29507            FR  production
# 43070            FR  production
# 47525            FR  production
# 56156            FR  production
# 82894            FR  production
# 86344            FR  production
# 109694           FR  production
# 111808           FR  production
# 116294           FR  production
# 129746           FR  production
# 138887           FR  production
# 154676           FR  production
# 156754           FR  production
# 163074           FR  production
# 166168           FR  production
# 180833           FR  production
# 191602           FR  production
# 209461           FR  production
# 211390           FR  production
# 212661           FR  production
# 231084           FR  production
# 240273           FR  production

# %%
session_id_user_agent_tuple_list = [tpl for tpl in set(list(zip(list(df.session_id), list(df.user_agent)))) if tpl[0]]

# %%
session_id_user_agent_tuple_dict = {key:value for key, value in session_id_user_agent_tuple_list}

# %%
session_id_user_agent_tuple_dict['lk6uli3v91z8qult']
# Out:
# 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; MDDR; .NET CLR 1.1.4322; Tablet PC 2.0; .NET4.0C; Windows Live Messenger 15.4.3555.0308)'

# %%
counter = 0
for tpl in session_id_user_agent_tuple_list:
    if not tpl[0]:
        #print(True)
        counter += 1

print(counter)
# Out:
# 0

# %%
len(session_id_user_agent_tuple_list)
# Out:
# 10535

# %%
session_id_user_agent_tuple_list = [('e8ou3xn663r8gmwu'	, 'UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532G) U2/1.0.0 UCBrowser/10.6.8.732 U2/1.0.0 Mobile')]
new_tuple = ('viza0aq49zkk62i0', 'Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firefox/8.0')
new_tuple2 = ('', 'Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firefox/8.0')

# %%
session_id_user_agent_tuple_list.append(new_tuple) if (new_tuple[0] != '' and new_tuple not in session_id_user_agent_tuple_list) else None

# %%
def create_session_id_user_agent_dict(session_col, user_agent_col):
    '''Finction that creates a dictionary with unique session_ids as keys and user_agents as values'''
    try:
        session_id_user_agent_tuple_list = [tpl for tpl in set(list(zip(list(user_agent_col), list(session_col)))) if tpl[1]]
        session_id_user_agent_tuple_dict = {key:value for key, value in session_id_user_agent_tuple_list}
        return session_id_user_agent_tuple_dict
    except Exception as e:
        print(F'Error while creating  the dictionary : {e}')
        return np.nan

# %%
session_id_user_agent_tuple_dict =  create_session_id_user_agent_dict(df.session_id, df.user_agent)

# %%
session_id_user_agent_tuple_dict
# Out:
# {'Mozilla/5.0 (Linux; Android 4.4.2; HS_9DTB37 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.111 Safari/537.36': 'pkj5puxoa08r7vw7',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-J500F Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.83 Mobile Safari/537.36': '1cnyjxi96884x196',
#  'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 13_5_8; en-US) AppleWebKit/532.5 (KHTML, like Gecko) Chrome/42.0.249.0 Safari/532.5': '2pmmum34cwfd8y19',
#  'Mozilla/5.0 (Windows NT 5.1; rv:13.0) Gecko/20120423 Firefox/13.0a2': '3iukb5s1l85msboj',
#  'Opera/9.80 (Windows Phone; Opera Mini/9.1.0/37.8814; U; hu) Presto/2.12.423 Version/12.16': '2x16281xvn9ghbxp',
#  'Mozilla/5.0 (Linux; Android 4.4.2; SGH-T399N Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.111 Mobile Safari/537.36': 'vpt3k5vgfolro4as',
#  'Opera/9.18 (X11; Linux i686; sl-SI) Presto/2.12.200 Version/10.00': '1drvs5oerlj56h74',
#  'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Mozilla/5.0 ; .NET CLR 1.7.4225; .NET CLR 4.0.56585; InfoPath.2)': 'm558wblg77qxgdey',
#  'Mozilla/5.0 (Linux; Android 4.4.4; XT1021 Build/KXC21.5-40) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.96 Mobile Safari/537.36': 'hdgeu1rqbu8lhkll',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like Mac OS X) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.8344.806 Mobile Safari/537.36': 'qdhbjdu4xv92b2iz',
#  'OneBrowser/4.2.0/Adr(Linux; U; Android 2.3.4; en-us; LG-LS855 Build/GRJ22) AppleWebKit/533.1 (KHTML, like Gecko) Mobile Safari/533.1': 'qukj3xtfrgzorhtb',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.2; Trident/4.0; .NET CLR 1.1.4322; InfoPath.3; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)': 'bkyx5jjemee85xue',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; APCPMS=^N20121205044244885276D964E27E6C32E13F_4787^; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2; InfoPath.3; 08gangn_AAP5766AE343C1)': '94jvsddhvyzmdogf',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-T585 Build/MMB29K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.85 Safari/537.36': 's4mpk7a9wku2pfdn',
#  'Mozilla/5.0 (Linux; Android 7.0; SAMSUNG-SM-G930A Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/5.0 Chrome/51.0.2704.106 Mobile Safari/537.36': 'zy5ash0x7mlo0c5o',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 1.1.4322; .NET CLR 3.5.30729; .NET4.0C; .NET4.0E)': 'wr3jr2ihipzdaudh',
#  'Mozilla/5.0 (Linux; Android 4.1.2; GT-N8010 Build/JZO54K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.125 Safari/537.36': 'ru0ualjop4h8sq06',
#  'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Chrome/8.0.552.215 Safari/534.10 ChromePlus/1.5.1.0': 't9nlxsozzw5ynclt',
#  'Mozilla/5.0 (Linux; Android 8.0.0; Pixel 2 Build/OPD3.170816.012) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.125 Mobile Safari/537.36': 'buul6nkn06utn6d6',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; chromeframe/26.0.1410.64; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; InfoPath.2; .NET CLR 1.1.4322; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; MS-RTC LM 8; .NET4.0C; .NET4.0E)': 'hll962oe2w479ri1',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 2.0.50727; .NET CLR 1.1.4322; .NET CLR 3.0.04506.30; InfoPath.2; .NET CLR 3.0.04506.648; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)': '83bm2febptgp515z',
#  'Mozilla/5.0 (Linux; Android 7.0; BLU Grand X LTE Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.111 Mobile Safari/537.36': 'e9wgj9ug7edsoqko',
#  'Mozilla/5.0 (Linux; Android 6.0; F3311 Build/37.0.A.1.151) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.89 Mobile Safari/537.36': 'qgdrgs0qu2rujb1v',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.5; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; MSN OptimizedIE8;ITIT)': 'oxp2z4rlfcsprup7',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-G920V Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/68.0.3440.91 Mobile Safari/537.36 SamsungBrowser/CrossApp/0.1.126': 'o5e03iotrvrn0twx',
#  'Mozilla/4.0 [en] (Win95; I)': 'hmbzs0eu8izn3577',
#  'Mozilla/5.0 (X11; CrOS x86_64 8743.87.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.101 Safari/537.36': '464h550pi0crkucg',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 1.1.4322; MS-RTC LM 8; .NET CLR 3.0.30618; .NET CLR 3.5.30729)': 'lap3guvckwqr51v0',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; de-de; LG-E460 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'ofvpgx8tb3imlq8s',
#  'Dalvik/2.1.0 (Linux; U; Android 8.0.0; MHA-L09 Build/HUAWEIMHA-L09)': 'e0gas2cxuqmlgq79',
#  'Mozilla/5.0 (Linux; Android 6.0; Google Nexus 5 - 6.0.0 - second Build/MRA58K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.106 Crosswalk/21.51.546.3 Mobile Safari/537.36': 'ggb9wqhs50i9ch9j',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-A520F Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/69.0.3497.100 Mobile Safari/537.36': 'n0m03qzhvgcvnr7s',
#  'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.9339.716 Mobile Safari/537.36': 'v7yc3eeruwec2ifi',
#  'Netscape/5.0 (Windows NT 6.2; rv:32.0) Gecko/2010112341 Netscape/32.0': 'vhrmeycdt8ftgqch',
#  'Mozilla/5.0 (SymbianOS/9.4; U; Series60/5.0 NokiaX6-00/12.0.091; Profile/MIDP-2.1 Configuration/CLDC-1.1 ) AppleWebKit/413 (KHTML, like Gecko) Safari/413': 'u7tqthwvsafsbwu5',
#  'Mozilla/5.0 (Linux; Android 4.1.2; SGH-T999 Build/JZO54K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.131 Mobile Safari/537.36': 'dg3xoy28th1dvthv',
#  'Mozilla/5.0 (X11; Linux x86_64; rv:55.0) Servo/1.0 Firefox/55.0': 'tu61n3trp09zwfwz',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 YaBrowser/16.6.0.8153 Safari/537.36': 'ooep8y7nzt96lc89',
#  'Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2_1 like Mac OS X; ko-kr) AppleWebKit/533.17.9 (KHTML, like Gecko) Version/5.0.2 Mobile/8C148 Safari/6533.18.5': 'f565dzewxy1hsk59',
#  'Mozilla/5.0 (Linux; U; Android 4.1.1; sv-se; Nexus One Build/CyanogenMod-8) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1': 'qpkjuapvn0thnspc',
#  'Mozilla/5.0 (Windows; U; Windows NT 10.0; en-US; Valve Steam GameOverlay/1478032887; ) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.21 Safari/537.36': 't6nd87a9aej146jb',
#  'Mozilla/5.0 (Linux; Android 5.1.1) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Focus/5.0 Chrome/66.0.3359.158 Mobile Safari/537.36': 'pvbqaeotrm7j6qyk',
#  'Opera/9.80 (MAUI Runtime; Opera Mini/4.4.31998/75.35; U; en) Presto/2.12.423 Version/12.16': 'zr0u9ba9wz07h9lr',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.4b) Gecko/20030615 Mozilla Firebird/0.6': '1fwojlqhu6tlt2vi',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS100470; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.1; .NET4.0C; .NET4.0E; .NET CLR 1.1.4322)': '3qjouhaax49kpyro',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Hyper/1.4.8 Chrome/58.0.3029.110 Electron/1.7.8 Safari/537.36': '3bnbhmfpy7il6uxs',
#  'Mozilla/5.0 (Linux; Android 4.4.2; SM-N900W8 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.83 Mobile Safari/537.36': 'u469mk56q9u4lm9c',
#  'Mozilla/5.0 (Linux; Android 7.1.2; Moto G4 Plus Build/NJH47F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Mobile Safari/537.36': 'crzg3tzae3rux7il',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; BRI/2; yie9)': 'pugh1bg1nb8wq6os',
#  'Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; Nexus 4 Build/JDQ39) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'ptg2j24l458eb1xz',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; pl-PL; rv:1.7.6) Gecko/20050321 Firefox/1.0.2': 'kaksepucovh1jbw9',
#  'Mozilla/5.0 (Linux; Android 4.3; MediaPad 7 Youth 2 Build/HuaweiMediaPad) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.98 Safari/537.36': 'opmfmaw38ck7k4x0',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/20100914 AskTbCDS/3.9.0.12758 Firefox/3.6.10 ( .NET CLR 3.5.30729)': 'svlvtfpfkdwh3vfa',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.2; OfficeLiveConnector.1.5; OfficeLivePatch.1.3; MS-RTC LM 8; .NET4.0C; .NET4.0E)': '053d8blylav62w0p',
#  'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 5.1; Trident/4.0; GTB7.5; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727; .NET4.0C)': 'j72cow67beq53swu',
#  'Opera/9.80 (BlackBerry; Opera Mini/8.0.35667/35.7827; U; en) Presto/2.8.119 Version/11.10': '3qzhzl07j0d968y9',
#  'Mozilla/5.0 (Linux; Android 7.1.2; GT-I9100 Build/NJH47D) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.125 Mobile Safari/537.36': 'jkpfuaa5lh5c6q2x',
#  'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; 360SE)': 'xn7y4uqw6f1e8v96',
#  'Mozilla/5.0 (Android 6.0.1; LG-H860 Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.9 NTENTBrowser/3.2.0.237 (Turkcell-TR) Mobile Safari/537.36': 'o4damcrtl5nigytf',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.91 Safari/537.36 Vivaldi/1.93.955.36': 'fwa26d0hwm5ytkwy',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.10) Gecko/2009042316 Firefox/3.0.10 Creative ZENcast v2.00.07': 'b8pf4pzn06zdod1o',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; de-de; GT-P3110 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30,gzip(gfe)': 'u59euz6ofzkdzdqt',
#  'Mozilla/5.0 (Linux; Android 7.1.2; VirtualBox Build/NZH54D) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.109 Safari/537.36': '0ccw61nfdhvu9mva',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.0.3705; .NET CLR 1.1.4322; Media Center PC 4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; MS-RTC EA 2)': 'zxqm8o70z38xs5at',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Win64; x64; Trident/7.0; .NET CLR 2.0.50727; SLCC2; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E)': 'obzut3ndiz8us87o',
#  'Nokia2700c-2/2.0 (07.81) Profile/MIDP-2.1 Configuration/CLDC-1.1 UCWEB/2.0 (Java; U; MIDP-2.0; en-US; Nokia2700c-2) U2/1.0.0 UCBrowser/9.5.0.449 U2/1.0.0 Mobile UNTRUSTED/1.0': '773fojgfvf5ilgs9',
#  'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 7 Build/MOB30D; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/49.0.2623.105 Safari/537.36': 'nb7ol3ieaeyw0jhf',
#  'Mozilla/5.0 (compatible; MSIE 9.0; AOL 9.7; AOLBuild 4343.19; Windows NT 6.0; Trident/5.0)': 'ucob6hyin5wup1qs',
#  'Mozilla/5.0 (Linux; U; Android 5.1.1; en-us; Redmi Note 3 Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/53.0.2785.146 Mobile Safari/537.36 XiaoMi/MiuiBrowser/9.2.8': 'xd4ub2r9pyq6u1gp',
#  'Mozilla/5.0 (Windows NT 5.1; rv:48.0) Gecko/20100101 Firefox/48.0 Light/48.0': 'sp42ncuufdbccfry',
#  'Mozilla/5.0 (iPad; CPU OS 10_2 like Mac OS X) AppleWebKit/602.3.12 (KHTML, like Gecko) Mobile/14C92 Safari/9537.53 Kitt/1.3.7/1': 'qm7bq2c7m9bptb4a',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/534.24 (KHTML, like Gecko) Chrome/11.0.696.77 Safari/534.24': 'l2acz7xit0zgrn7c',
#  'Mozilla/5.0 (Linux; Android 7.1.2; A95X-R1 Build/A95X_R1; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/64.0.3282.137 Safari/537.36': 'q7rllvyy3gm9wh6s',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-G935F Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/59.0.3071.125 Mobile Safari/537.36 Line/7.8.1/IAB': 'zdbira12d9t7erax',
#  'Mozilla/5.0 (Linux; U; Android 4.0.3; iw-il; LG-E612f Build/IML74K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'zbjlxlma7wrutonr',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; Sky Broadband; chromeframe/27.0.1453.116; GTB7.5; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C)': 'a4dchupetgrejubd',
#  'Mozilla/5.0 (Linux; U; Android 4.1.1; sv-se; GT-N7100 Build/JRO03C) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': '05dbfhptb8wzftuk',
#  'Mozilla/5.0 (Linux; Android 6.0; LG-UK495 Build/MRA58K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.158 Safari/537.36': 'wiwf7peeorfsf7uk',
#  'Mozilla/5.0 (Linux; Android 4.0.4; GT-S7560M Build/IMM76I) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.166 Mobile Safari/535.19': '5wbt9xbw1fc0udyx',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/7.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET4.0C; .NET4.0E; HPNTDFJS; Media Center PC 6.0; H9P; InfoPath.2)': '15fjeax5e4nly7h8',
#  'Mozilla/5.0 (Linux; U; Android 5.1.1; en-US; LG-K420 Build/LMY47V) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 UCBrowser/11.0.5.850 U3/0.8.0 Mobile Safari/534.30': 'e8d6tf5fxnepwtmc',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506; InfoPath.2)': 'gio5nrwthzdazkrn',
#  'Mozilla/5.0 (X11; U; UNIX; en-UK) Gecko/20250617 (Cardamon, like Gecko, Trident 16) Aurora Borealis 2.4.5a': 'ilbte4fxxcwyzfk3',
#  'Mozilla/5.0 (Linux; U; Android 4.2.2; en-US; GT-I9082 Build/JDQ39) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 UCBrowser/11.1.0.882 U3/0.8.0 Mobile Safari/534.30': '4l2xeeidku7b9ahm',
#  'Mozilla/5.0 (Linux; Android 5.0.2; SM-G530BT Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.85 Mobile Safari/537.36': '9ymctb2bgc670n37',
#  'Mozilla/5.0 (Android 5.0.2; SM-G360M Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.9 NTENTBrowser/3.1.0.178 (Turkcell-TR) Mobile Safari/537.36': '0g14yvjfgbt3zm7h',
#  'Mozilla/5.0 (Linux; Android 5.0.2; SM-G530M Build/LRX22G; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/66.0.3359.106 Mobile Safari/537.36 [FB_IAB/FB4A;FBAV/181.0.0.36.82;]': 'hn7uqynn2q6n3rx1',
#  'Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; Intex Cloud Y11 Build/W97055A3) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': '6q7upe2vv9qg220f',
#  'Mozilla/5.0 (Linux; U; Android 2.3.7; es-mx; ST27a Build/6.0.B.3.191) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1': '18uqc6hd0cqwld8l',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; Kmart; Q312461; SHC; .NET CLR 1.1.4322; .NET CLR 3.0.04506.30; .NET CLR 3.0.04506.648; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; .NET4.0E; InfoPath.3; .NET CLR 2.0.50727)': '6h72ox3byeovcwjf',
#  'Mozilla/5.0 (iPad; CPU OS 11_0 like Mac OS X; en-MT) AppleWebKit/538.20.14 (KHTML, like Gecko) Version/10.1.3 Mobile/8C38a Safari/538.20.14': '2e1o7yax68r7wfwv',
#  'Mozilla/5.0 (Linux; Android 6.0.1; LS-4505 Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.158 Mobile Safari/537.36 OPR/47.2.2249.130937': 'ydc7kyjocqkimd88',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET4.0C; .NET4.0E; InfoPath.3; BWB31012012)': 'os9m3d6fn2vzf95o',
#  'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_3; en-us; Silk/1.0.143.1-Gen4_11004910) AppleWebKit/533.16 (KHTML, like Gecko) Version/5.0 Safari/533.16 Silk-Accelerated=true': 'xbt8tw8tmqunvkt9',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like Mac OS X) AppleWebKit/604.1.34 (KHTML, like Gecko) GSA/41.0.178428663 Mobile/15A372 Safari/604.1': '07dlt2h15b1jhepi',
#  'Mozilla/5.0 (Linux; U; Android 4.0.3; es-us; Sprint APC715CKT Build/IML74K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'ej3kuda85ug7lq10',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-G920S Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.111 Mobile Safari/537.36': '6d209us1nny2srq4',
#  'Opera 24.0.1634': 'gpcklopfh1l62rc6',
#  'Mozilla/5.0 (Linux; Android 4.4.3; S7 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.0.0 Mobile Safari/537.36': 'tghs5q4p5z4jj943',
#  'Mozilla/5.0 (Linux; Android 7.0; Moto C Plus Build/NRD90M.04.026; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/66.0.3359.158 Mobile Safari/537.36': '9suravkpl9usq1x4',
#  'Mozilla/5.0 (Linux; U; Android 4.4.2;  zh-cn; S7; Android/4.4.2; Release/10.22.2015)  AppleWebKit/534.30 (KHTML, like Gecko) Mobile Safari/534.30': '70hjx6bxgu2r9lls',
#  'Mozilla/5.0 (iPad; CPU OS 10_3 like Mac OS X) AppleWebKit/602.1.50 (KHTML, like Gecko) GSA/29.0.159059490 Mobile/14E277 Safari/602.1': 'c3tlvrkuh8u49dk3',
#  'Mozilla/5.0 (Linux; U; Android 4.0.4; es-do; LG-P768 Build/IMM76L) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': '0ypzsxwvq2jer4gs',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; en-us; SCH-R950 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30 USCC-R950': '7gz5qgajyogeyki3',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS105649; GTB7.5; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; .NET4.0E)': 'bemkrz8kvmy92fef',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-G532M Build/MMB29T; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/69.0.3497.100 Mobile Safari/537.36 [FB_IAB/Orca-Android;FBAV/190.0.0.22.95;]': 'p0b7rekxrfd1541m',
#  'Mozilla/5.0 (Linux; Android 7.0; Moto C Build/NRD90M.063; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/66.0.3359.158 Mobile Safari/537.36 [FB_IAB/Orca-Android;FBAV/181.0.0.12.78;]': 'rnoedckmtdvridyv',
#  'Mozilla/5.0 (Linux; Android 4.3; C6530N Build/JLS36C) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36': 'zwuwgb7iflgm189f',
#  'Mozilla/5.0 (Linux; Android 4.4.2; VK810 4G Build/KOT49I.VK81022B) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.91 Safari/537.36': 'n5iwvepcfx324p41',
#  'MOT-EX431G/[TF359486041367093498927918102889162] Obigo/Q03C MMP/2.0': '6t3jewk487w87i1g',
#  'UCWEB/2.0 (MIDP-2.0; U; Adr 5.1.1; id; SM-J120G) U2/1.0.0 UCBrowser/10.7.9.856 U2/1.0.0 Mobile': 'a93yy9geagtulqu6',
#  'Mozilla/5.0 (Linux; Android 7.1.2; Redmi Note 3 Build/NHG47L; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/59.0.3071.82 Mobile Safari/537.36': 'un3jektfokrkwba3',
#  '{Mozilla/5.0 (X11; Linux i686; rv:64.0) Gecko/20100101 Firefox/64.0}': 'qklgnqyozmocw0kr',
#  'Mozilla/5.0 (Linux; Android 4.4.2; A1-810 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.133 Safari/537.36': 'b6d4v6ab0e1z0hqf',
#  'Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US; rv:1.9.1.10) Gecko/20100504 Firefox/3.5.10 ( .NET CLR 3.5.30729; .NET4.0C) FBSMTWB': 'hpdnn6iv9rli4gfn',
#  'UCWEB/2.0 (MIDP-2.0; U; Adr 2.2.2; en-US; LG-P970) U2/1.0.0 UCBrowser/9.2.0.419 U2/1.0.0 Mobile': '0il4k7zpx9631nyz',
#  'Mozilla/5.0 (X11; Linux aarch64) AppleWebKit/537.36 (KHTML, like Gecko) Falkon/3.0.1 Chrome/65.0.3325.230 Safari/537.36': 'mha8ez5d6y5fx19a',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:42.0) Gecko/20100101 Firefox/42.0': 'yilnciqfd617484i',
#  'Mozilla/5.0 (Linux; Android 4.3; XT1033 Build/14.10.0Q3.X-76-LCG-9) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.78 Mobile Safari/537.36': 'tpk6379swedytl1a',
#  'Mozilla/5.0 (Macintosh; U; Intel Mac OS X; fr) AppleWebKit/419 (KHTML, like Gecko) Safari/419.3': 'g6otnb2p6b214ntp',
#  'Mozilla/5.0 (Linux; U; Android 4.3; th-th; GT-I9300 Build/JSS15J) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': '682oi7qd2i53fnpm',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS100194; .NET CLR 1.0.3705; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)': 'n3d4w8rn28nk4e07',
#  'Mozilla/5.0 (Linux; Android 8.0; SM-G965F Build/NJH47F) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2939.0 Mobile Safari/537.36': '3qd6v49gwoc1kv72',
#  'SAMSUNG-GT-E2252 Opera/9.80 (J2ME/MIDP; Opera Mini/4.4.29991/71.132; U; en) Presto/2.12.423 Version/12.16': '18wf06g1x5b9bzxg',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3; printmade=3.0.0.7)': '1e3xb8k97x3dhrdy',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.68 Safari/537.36': '69wf898gz4b68w9i',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/537.22 (KHTML, like Gecko) Chrome/25.0.1364.172 Safari/537.22 AlexaToolbar/alxg-3.1': 'ijeii0e797v7du1d',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET4.0C; .NET4.0E; .NET CLR 1.1.4322; .NET CLR 3.5.30729; InfoPath.3)': '9d3aopujyevnf1ue',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; chromeframe/32.0.1700.107; InfoPath.1; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 1.1.4322; AskTbORJ/5.15.23.36191)': 'ehmi687rhruxrn8e',
#  'Opera/9.80 (MAUI Runtime; Opera Mini/4.4.33576/63.203; U; en) Presto/2.12.423 Version/12.16': '8y3bnrbkq21y24za',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_4) AppleWebKit/536.30.1 (KHTML, like Gecko) Safari/522.0': '4d98fo2rp6eqkcwj',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_2_5 like Mac OS X) AppleWebKit/604.5.6 (KHTML, like Gecko) Mobile/15D60 [FBAN/FBIOS;FBAV/179.0.0.50.82;FBBV/116150041;FBDV/iPhone8,4;FBMD/iPhone;FBSN/iOS;FBSV/11.2.5;FBSS/2;FBCR/mt:s;FBID/phone;FBLC/sv_SE;FBOP/5;FBRV/0]': 'e8rtcb4z2jtyx402',
#  'Opera/9.80 (Android; Opera Mini/7.5.33391/83.113; U; en) Presto/2.12.423 Version/12.16': 'gkhrayrxopzgnkug',
#  'Mozilla/5.0 (Linux; Android 5.1.1; LGMS330 Build/LMY47V; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/64.0.3282.137 Mobile Safari/537.36': 'a2j93uz87ixmrtst',
#  'Mozilla/5.0 (Linux; U; Android 4.4.2; en-US; SM-G130H Build/KOT49H) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 UCBrowser/10.8.5.725 U3/0.8.0 Mobile Safari/534.30': 'dgdfvujgqtgj6rh4',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E302 MobileIron/2.3.1 Version/11.3.1 Safari/605.1.15': '5h0v5gs0wpzm011t',
#  'NokiaX2-00/5.0 (08.25) Profile/MIDP-2.1 Configuration/CLDC-1.1 nokiax2-00/UC Browser8.0.3.107/70/355': 'iuilwk29oscbojjw',
#  'Mozilla/5.0 (Linux; Android 6.0; BLL-L22 Build/HUAWEIBLL-L22; en-us) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.111 Mobile Safari/537.36 Puffin/7.5.1.20499AP': '1ow2x8el3xz5dkhs',
#  'Opera/9.80 (Android; Opera Mini/10.0.1884/37.6488; U; id) Presto/2.12.423 Version/12.16': 'x9flqvpdylk3odmy',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-G532G) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.80 Mobile Safari/537.36': 'ayu7f53oy22dw9bd',
#  'Mozilla/5.0 (Linux; Android 5.1.1; Z717VL Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.0 Mobile Safari/537.36': 'dz2lbbhpeii2dmyd',
#  'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.12 (KHTML, like Gecko) Maxthon/3.0 Chrome/18.0.966.0 Safari/535.12': '4n1h655pn5hgsoey',
#  'Mozilla/5.0 (Linux; Android 4.4.4; SM-S820L Build/KTU84P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.76 Mobile Safari/537.36': '5j4j8arpwgu97cjx',
#  'Mozilla/5.0 (Linux; Android 5.0.1; SCH-R970 Build/LRX22C) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.83 Mobile Safari/537.36': 't8qed6o5lj89yz56',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; de-de; GT-I9300 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'ea1c0w1f5e836dme',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/534.19 (KHTML, like Gecko) Chrome/11.0.661.0 Safari/534.19': '3amadii1dvrbywbc',
#  'Mozilla/5.0 (Linux; Android 8.0.0; SM-G930P Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.137 Mobile Safari/537.36': '0fpdspjs5fap1qeq',
#  'Safari5528.16 CFNetwork/422.15.2 Darwin/9.6.0 (i386) (MacBookPro1%2C2)': 'i7kk6w4w0lgvuz64',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; he-; GT-I9300 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'lyeab87n0lc9bqdx',
#  'Konqueror\\t3.3\\tMozilla/5.0 (compatible; Konqueror/3.3; Linux; x86_64) (KHTML, like Gecko)': 'ud9mzud5piz30v9w',
#  'Mozilla/5.0 (Linux; Android 4.4.4; SAMSUNG-SGH-I337 Build/KTU84P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.76 Mobile Safari/537.36': '6ycfg7c3fiixzc94',
#  'Mozilla/5.0 (X11; U; Linux x86_64) AppleWebKit/536.21 (KHTML, like Gecko) Chrome/56.0.2712.91 Safari/536.21': 'sqszdhgrkb3e13w1',
#  'Mozilla/5.0 (Linux; Android 4.3; D2303 Build/18.0.C.1.13) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.94 Mobile Safari/537.36': 't1tnr5k26c3qt0j8',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; en-us; LGMS659 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30evme-launcher': '7osxld33o5zfxop8',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS122833; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)': 'cn6ay5523omrzmar',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-J710MN Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/69.0.3497.100 Mobile Safari/537.36 Instagram 64.0.0.14.96 Android (24/7.0; 320dpi; 720x1280; samsung; SM-J710MN; j7xelte; samsungexynos7870; es_US; 125398468)': 'dqbsn6h7os3tbkgi',
#  'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.8) Gecko/20100728 Firefox/3.6.8 CometBird/3.6.8': '0f8m02o4mzsqn1ii',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) GSA/5.5.50480 Mobile/11D257 Safari/9537.53': '20d41896h538wl2s',
#  'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P350f Build/FRG83G) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1 MMS/LG-Android-MMS-V1.0/1.2': '715rpl899f6416wn',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; rv:38.0) Gecko/20100101 Thunderbird/38.5.1 Lightning/4.0.5.1': '5285prnwp7r9tu80',
#  'Mozilla/5.0 (Linux; U; Android 4.4.3; en-za; HTC_One Build/KTU84L) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': '0ysf41xyokcd9v1x',
#  'Opera/9.80 (SpreadTrum; Opera Mini/4.4.31492/63.235; U; hi) Presto/2.12.423 Version/12.16': 'qfkgex8n4a939y5l',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30; .NET CLR 3.0.04506.648; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; .NET4.0E; InfoPath.3; yie8)': '3xu9fd2w62ai0y96',
#  'Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; NJ820+ Build/JDQ39) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30 Maxthon': '63wixww5eprvucc7',
#  'Mozilla/5.0 (Linux; U; Android 4.0.4; en-us; AW710 Build/IMM76D) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'niqtv93q844db1uc',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET4.0C; .NET4.0E; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; SE 2.X MetaSr 1.0)': 'fyofgyodanxox9rl',
#  'Opera/9.80 (BlackBerry; Opera Mini/8.0.35659/67.377; U; es) Presto/2.12.423 Version/12.16': 'l8roxcdzp00brr8j',
#  'Mozilla/5.0 (Linux; Android 7.1.2; Redmi 5A Build/N2G47H; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/67.0.3396.87 Mobile Safari/537.36 drive2client/3.55.670 (Android 7.1.2;Smartphone;Xiaomi Redmi 5A;Features:143)': 'f7l0igae5628izu8',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; es-ES; rv:1.9.1.2) Gecko/20090729 Firefox/3.5.2 ( .NET CLR 3.5.30729)': 'bh93qudewwmk1p3l',
#  'SAMSUNG-GT-C3322i Opera/9.80 (J2ME/MIDP; Opera Mini/7.1.33886/37.9261; U; en) Presto/2.12.423 Version/12.16': 'pzqvigb0w1pv3fb3',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; MDDC; BRI/1; .NET4.0C; BRI/2; MS-RTC LM 8)': 'r7lqxo6z1b6akmaf',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS114132; GTB7.5; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; InfoPath.2)': 'ocncg53je73ttxk2',
#  'Mozilla/5.0 (Linux; Android 6.0.1; LGLS676 Build/MXB48T) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.125 Mobile Safari/537.36': '27arzicb9n10dc70',
#  'Mozilla/5.0 (Linux; Android 5.1.1; SAMSUNG SM-T670 Build/LMY47X) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/3.5 Chrome/38.0.2125.102 Safari/537.36': 'z8h8p10xh5aj0zxf',
#  'Mozilla/5.0 (Windows NT 5.1; WOW64; rv:38.0) Gecko/20100101 Thunderbird/38.7.0 Lightning/4.0.7': 'x8zap0akav3iimra',
#  'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) coc_coc_browser/47.0 Chrome/41.0.2272.127_coc_coc Safari/537.36': 'kutpn82m1rgk2muu',
#  'Opera/9.80 (Windows NT 6.0; ) Version/21': 'ydxr67vcovj30p40',
#  'Opera/9.80 (J2ME/MIDP; Opera Mini/4.5.40380/37.8025; U; es) Presto/2.12.423 Version/12.16': 'ih8le1cb7sqlwmx4',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.36 Safari/537.36': 'g5xso1rdah4dpeu3',
#  'Opera/9.80 (Android; Opera Mini/10.0.1884/37.7011; U; ru) Presto/2.12.423 Version/12.16': 'gdtd8rgj13y6r10z',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; id-id; LG-P765 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'yy4de7h2xoa4rfa7',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2650.0 Iron Safari/537.36': 'ogyebzjrlrij8gqz',
#  'Mozilla/5.0 (Linux; Android 4.4.2; HP SlateBook 14 PC Build/4.4.2-17r25.1-11-11) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.135 Safari/537.36': '58yezsq5z02ogwuu',
#  'Mozilla/5.0 (Linux; Android 4.2.2; IdeaTab S6000-H Build/JDQ39) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36': 'fbgs2fy3a99svqoq',
#  'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36': 'tj3p7seybgekz7cg',
#  'NokiaC2-01/5.0 (10.50) Profile/MIDP-2.1 Configuration/CLDC-1.1 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2;.NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; InfoPath.2)/UC Browser7.9.0.102/69/352 UNTRUSTED/1.0': '5kjddfwuo80ntpen',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-J327V Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.91 Mobile Safari/537.36': 'l1zmkgd6wd20a2km',
#  'Opera/9.80 (Linux mips; ) Presto/2.12.407 Version/12.51 MB97/0.0.34.18 (LUXOR, Mxl661LG32, wireless) VSTVB_MB97  SmartTvA/3.0.0': '2timre21j4xv28f1',
#  'Opera/9.80 (Series 60; Opera Mini/7.1.32444/66.330; U; pl) Presto/2.12.423 Version/12.16': 'ttbj4gscubb25ici',
#  'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_4; en-us) AppleWebKit/533.19.4 (KHTML, like Gecko) Version/5.0.3 Safari/533.19.4 FBSMTWB': 'j0rve78l21paoo85',
#  'Mozilla/5.0 (Linux; Android 4.3; SGP311 Build/10.4.B.0.577) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.59 Safari/537.36': 'u5jlyqz7rik3wz7j',
#  'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.1189.66 Mobile Safari/537.36': 'egbnlgnwud6bx95c',
#  'Mozilla/5.0 (Windows NT 5.1; rv:14.0) Gecko/ /14.0': 'wfb1s20ju04i5g3d',
#  'Mozilla/5.0 (Linux; Android 4.1.2; GT-P5100 Build/JZO54K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.68 Safari/537.36': '1m17h2vcumheap43',
#  'Opera/9.80 (Windows NT 6.1; U; it) Presto/2.10.229 Version/11.61': '4k9jqef9re20dzp6',
#  'Mozilla/5.0 (iPhone 4; CPU iPhone OS 6_1_2 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 MQQBrowser/5.0.5 Mobile/10B146 Safari/8536.25': '3bwsl4j409k2netx',
#  'Mozilla/5.0 (Linux; Android 6.0.1; LG-D838 Build/MOB31K) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/6.2 Chrome/56.0.2924.87 Mobile Safari/537.36': 'zvjfdsvlnuhmpd9p',
#  'Mozilla/5.0 (Linux; U; Android 4.4.2; en-au; HTC_0P9C2 Build/KOT49H) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'vcn87ub4x0gm4jgu',
#  'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/537.13+ (KHTML, like Gecko) Version/5.1.7 Safari/534.57.2': 'ffisxosa7opr67j3',
#  'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0; SLCC1; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729)': 'mbcmokcmuszo032n',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; AskTB5.6; Lunascape 6.8.1.25906)': '1ygb0j2flj3iqy7p',
#  'Mozilla/5.0 (Linux; U; Android 6.0; en-US; Micromax Q402 Build/MRA58K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 UCBrowser/11.0.5.850 U3/0.8.0 Mobile Safari/534.30': 'yepv52j9q57ygvwi',
#  'Mozilla/5.0 (Android 5.0.1; HTC6525LVW Build/LRX22C) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.9 NTENTBrowser/3.2.0.211 (DigitalTurbine-US) Mobile Safari/537.36': 'nszlqbxvy9cx0l4n',
#  'Mozilla/5.0 (X11; U; U; Linux x86_64; en-us) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36 Puffin/7.7.0.30144AP': '0wq813ozf6cckal6',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.99 Safari/537.36': 'x1e4tx0f0o855coz',
#  'Mozilla/5.0 (Linux; Android 7.0; vivo 1714 Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.83 Mobile Safari/537.36': 'm0opcblriin81qak',
#  'Mozilla/5.0 (Linux; Android 7.0; Moto G (5) Plus Build/NPNS25.137-15-11) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.84 Mobile Safari/537.36': 'sb8jjmfw1a6hrnhz',
#  'Mozilla/5.0 (Linux; Android 7.1.1; Z983 Build/NMF26F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.111 Mobile Safari/537.36': 'dg5h7lt38kek3b3k',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.4; BTRS105073; .NET CLR 1.1.4322; maxwebsearchtoolbar_Maxwebsearch)': 'yqtyujr9tdyaa5fg',
#  'Mozilla/5.0 (Linux; U; Android 4.2.2; fi-fi; GT-P5210 Build/JDQ39) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30': 'kcpyf3za7207nhty',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; FunWebProducts; FBSMTWB; GTB5; .NET CLR 1.0.3705; .NET CLR 1.1.4322; Media Center PC 4.0; Windows-Media-Player/10.00.00.3990)': '3scv3r0zwodap5m5',
#  'Mozilla/5.0 (Linux; Android 5.1.1; LG-K130 Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.89 Mobile Safari/537.36': 'rib9d8tof3h00sod',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; fr; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7': 'tb1x91tlhnsvkb1z',
#  'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0; SiteKiosk 8.8 Build 1686)': '2reuic6edl3x7kkt',
#  'Mozilla/5.0 (compatible; MSIE 10.5 Windows NT 6.1; WOW64; Trident/6.1)': 'q0cgjp5hdy7sori0',
#  'Mozilla/5.0 (Linux; U; Android 5.1.1; en-US; vivo Y51L Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2987.108 UCBrowser/12.9.5.1146 Mobile Safari/537.36': '59bvmdh4z1sdlh8k',
#  'Opera/9.60 (J2ME/MIDP; Opera Mini/4.0.10992/786; U; es) Presto/2.2.0': 'nlm25qlp878338wq',
#  'Opera/9.80 (Android; Opera Mini/7.6.35843/35.5247; U; en) Presto/2.8.119 Version/11.10': 's4zgjc1sot1lgga5',
#  'Mozilla/5.0 (Linux; Android 7.0; PRA-LX1 Build/HUAWEIPRA-LX1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.116 Mobile Safari/537.36': 'hw6gz255r5uofqy7',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/534.53.11 (KHTML, like Gecko) Stainless/0.8 like Version/5.1 Safari/534.48.3': 'gz48izxmckgxbtiw',
#  'Mozilla/5.0 (Windows NT 6.0; Win64; x64) AppleWebKit/605.4.5 (KHTML, like Gecko) Chrome/58.0.2949.24 Safari/605.4.5': 'nncpdkebu7v8prge',
#  'Mozilla/5.0 (Linux; U; Android 4.2.2; en-gb; V97 HD Build/LR-97JC) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30': '3a175qmkunw3ndgs',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3622.0 Safari/537.36': 'yb7t5zrbf0nkxfdz',
#  'Mozilla/5.0 (Linux; U; Android 5.1.1; en-us; SM-G920V Build/LMY47X) AppleWebKit/537.16 (KHTML, like Gecko) Version/4.0 Mobile Safari/537.16 Chrome/33.0.0.0': '4hoafyhmtwhlajlx',
#  'Mozilla/5.0 (Linux; Android 9; Pixel Build/PPR2.181005.003) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 YaBrowser/18.10.1.887.00 Mobile Safari/537.36': 'vpyf6wuee9sl1mqm',
#  'Mozilla/5.0 (Linux; U; Android 4.4.2; de-de) AppleWebKit/537.36 (KHTML, like Gecko)  Chrome/30.0.1599.114 Safari/537.36 Puffin/3.7.1.504AT Mobile': 'e2yp5jz40c85k2jw',
#  'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.23 Safari/537.36 IR/1': 'tgw5i764hyk4t12c',
#  'Mozilla/5.0 (Linux; Android 6.0; CS28 Build/MRA58K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.84 Mobile Safari/537.36': 'a0dficn70pjl98vi',
#  'Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US; rv:1.9.0.1) Gecko/2008070208 Firefox/3.0.1 (.NET CLR 3.5.30729) FBSMTWB': 'utht0itl0u6lc483',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.5; .NET CLR 1.0.3705; .NET CLR 1.1.4322; Media Center PC 4.0; .NET CLR 3.0.04506.30; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; BOIE8;ENUS)': 'caukqt5pcnk20gda',
#  'Mozilla/5.0 (Linux; Android 8.0.0; SM-N950U Build/R16NW) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.70 Mobile Safari/537.36': 'h8h2wn64oas44x5z',
#  'Mozilla/5.0 (Linux; U; Android 4.0.4; ja-jp; A700 Build/IMM76D) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30': 's47nt0twcbo7oxfb',
#  'Mozilla/5.0 (Linux; Android 4.4.2; EC6108V8 Build/Sbox8B40A) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.137 Safari/537.36': 'v03rxlmlld0c1y8q',
#  'Mozilla/5.0 (Linux; U; Android 4.0.3; en-gb; SmartTab1 Build/IML74K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30': 'iugtjavil9s6gijm',
#  'Mozilla/5.0 (Intel Mac OS X) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.84 Safari/537.36 OPR/38.0.2220.31': 'xnez844xkxzxm45m',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.112 Safari/537.36': 'uz7vuvjqrxg8mmt7',
#  'Mozilla/5.0 (Linux; Android 7.1.1; Moto E (4) Build/NCQ26.69-46-5-4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.126 Mobile Safari/537.36': '1zph0s1pf7jlm1kz',
#  'Mozilla/5.0 (Linux; U; Android 2.3.3; en-fi; HTC_DesireZ_A7272 Build/GRI40) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1': 'njm3pt1zdke3hszs',
#  'Mozilla/5.0 (compatible; MSIE 4.0; Linux i686; SV1; Trident/1.0)': 'pu3h3g5h59fj2bqp',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-T350 Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/6.2 Chrome/56.0.2924.87 Safari/537.36': 'qe5w6mpwfqhvfxqq',
#  'Mozilla/5.0 (Macintosh; U; Intel Mac OS X; en-US; rv:1.8.1.9) Gecko/20071025 Firefox/2.0.0.9': 'jde92l6zg72p5spt',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.5; InfoPath.1; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; MS-RTC LM 8; McAfee; yie8)': '1d1wqyh77yma5ax0',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/525.13 (KHTML, like Gecko) Chrome/0.X.Y.Z Safari/525.13': 'xoi7g61i3x3051qz',
#  'Mozilla/5.0 (Windows NT 5.1; rv:44.0) Gecko/20130406 Firefox/44.0': 'a0bsc7cuq2adrnj7',
#  'Mozilla/5.0 (Linux; U; Android 4.3.1; en-us; Nexus 7 Build/JLS36I) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30': 'wna6rlexn5hazlk8',
#  'Mozilla/5.0 (Linux; Android 8.1.0) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Focus/4.1 Chrome/65.0.3325.144 Mobile Safari/537.36': 'cgja6fzwc23j8eah',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-J500FN Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.91 Mobile Safari/537.36 OPR/42.7.2246.114996': 'sk6n5h57izr6aop3',
#  'Mozilla/5.0 (Linux; Android 4.2.2; en-nz; SAMSUNG GT-I9505 Build/JDQ39) AppleWebKit/535.19 (KHTML, like Gecko) Version/1.0 Chrome/18.0.1025.308 Mobile Safari/535.19': 'er2e5agifbfjieev',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_4 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15F79 [FBAN/FBIOS;FBAV/183.0.0.41.81;FBBV/119182652;FBDV/iPhone8,4;FBMD/iPhone;FBSN/iOS;FBSV/11.4;FBSS/2;FBCR/T-MobileCZ;FBID/phone;FBLC/cs_CZ;FBOP/5;FBRV/119541743]': 'xtsgnv8w6pmx08hf',
#  'Mozilla/5.0 (Linux; Android 8.1.0; ONEPLUS A5010 Build/OPM1.171019.011; rv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Rocket/3.1.0(6550) Chrome/69.0.3497.91 Mobile Safari/537.36': '8v8bpw5pepmof83d',
#  'Mozilla/5.0 (Linux; Android 8.1.0; Mi A1 Build/OPM1.171019.026) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Mobile Safari/537.36': 'cv09mgt7grtr4ome',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB6.6; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; MDDR)': 'gu09y2ihldwp3gpn',
#  'Opera/12.02 (Android 4.1; Linux; Opera Mobi/ADR-1111101157; U; en-US) Presto/2.9.201 Version/12.02': '3qpib1zn6tbmvg8g',
#  'Mozilla/5.0 (Linux; Android 6.0.1; A0001 Build/MMB29X) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.124 Mobile Safari/537.36': 'lpqqwuesfqr019jz',
#  'Mozilla/5.0 (Linux; U; Android 2.2; es-us; GT-I9000B Build/FROYO) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1': 'jyvz4vof2gvdkfin',
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-GB; rv:1.9) Gecko/2008052906 Firefox/3.0/UoM Desktop (.NET CLR 3.5.30729)': '0t5e40u45qbblt6l',
#  'Mozilla/5.0 (Linux; Android 4.0.4; ST23i Build/11.0.A.5.5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.92 Mobile Safari/537.36': '60voy8okmv15vyo1',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 12_0_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/16A404 [FBAN/MessengerForiOS;FBAV/188.0.0.38.99;FBBV/127861730;FBDV/iPhone8,1;FBMD/iPhone;FBSN/iOS;FBSV/12.0.1;FBSS/2;FBCR/movistar;FBID/phone;FBLC/es_LA;FBOP/5]': '7tplfwvporvy5ei3',
#  'Mozilla/5.0 (Linux; Android 6.0; Sprint Build/MRA58K; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/60.0.3112.107 Mobile Safari/537.36': 'fxhw9gefcwaa6g2q',
#  'Mozilla/5.0 (Linux; U; Android 6.0.1; en-us; MI MAX Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/53.0.2785.146 Mobile Safari/537.36 XiaoMi/MiuiBrowser/9.1.3': '1fp1y3vqnehyc24n',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:50.0) Gecko/20100101 Firefox/50.0 Waterfox/50.0': 'd2hoczjww5c5tlpy',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/534.24 (KHTML, like Gecko) Chrome/46.0.2490.85 Safari/534.24 XiaoMi/MiuiBrowser/8.2.8': 'p1r4m6zbvri6czs8',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-J330FN Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.158 Mobile Safari/537.36': 'qu8alo1omtee6i4e',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.5; (R1 1.6); BRI/2; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)': 'skn6n9dbbu9706is',
#  'Mozilla/5.0 (Linux; Android 5.1; QMobile S3 Build/LMY47I) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Mobile Safari/537.36': 'ewbqx61wt2mnka1u',
#  'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.7.1294 Chrome /39.0.2048.101 Safari/537.36': 'xkk7i9ay6vf7ihzt',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.3; Win64; x64; Trident/8.0; Touch; .NET4.0C; .NET4.0E; Tablet PC 2.0)': '8gjqq3uu3t7w9b5f',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; CMDTDF; InfoPath.1; .NET CLR 1.1.4322; .NET4.0C; .NET4.0E; IPH 1.1.21.4019)': '8n7fjyeu6qq1gt2l',
#  'Mozilla/5.0 (Macintosh; U; Intel Mac OS X; en; rv:1.8.1.16) Gecko/20080803 Camino/1.6.3 (like Firefox/2.0.0.16)': 'y81qdiy5eg6sq0xh',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; .NET CLR 3.0.04506.30; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727; .NET4.0C; .NET4.0E; GOC)': '9lvfoz1pnk1r2wdn',
#  'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0; MSN 9.0;MSN 9.1;MSN 9.6;MSN 10.0;MSN 10.2;MSN 10.5;MSN 11; MSNbMSNI; MSNmes-es; MSNcOTH) like Gecko': 'jx71xfa81b4xppbr',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:51.0) Gecko/20170125 Firefox/51.0; xs-neYTQYm8x5w;CvMViE;': 'vpa6vovnw4zwroqf',
#  'Mozilla/5.0 (Linux; Android 6.0; RCT6873W42M Build/MRA58K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.116 Safari/537.36': '0hxu7dgnbck2yb6g',
#  'Mozilla/5.0 (Linux; Android 6.0.1; Micromax AQ4502 Build/MOB30R; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/51.0.2704.106 Mobile Safari/537.36[FBAN/EMA;FBLC/en_GB;FBAV/24.0.0.3.186;]': 'y888751g0hjb0zy1',
#  'Mozilla/5.0 (Linux; Android 4.4.2; DL700D Build/86V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36': '6xo8u23wgsxtmwmu',
#  'Mozilla/5.0 (Windows NT 6.2; rv: 23.0.1) Gecko/20120406 Firefox/23.0.1': 'w598mqnwnvvidse0',
#  'Mozilla/5.0 (Linux; Android 5.0; BLU STUDIO C 5+5 Build/LRX21M) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/37.0.0.0 Mobile Safari/537.36': 'f3084cj7sgrfwfpc',
#  'Mozilla/5.0 (Linux; Android 7.0; SM-T815 Build/NRD90M; en-gb) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.117 Safari/537.36 Puffin/7.0.3.17762AT': '093cbv1ane03bvtk',
#  'Mozilla/5.0 (Linux; U; Android 2.3.5; en-us; LENOVO-Lenovo-A396/1.0 Android/2.3.5 Release/05.29.2014 Browser/AppleWebKit533.1 Build/MDroid2.3.5) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1 MxBrowser/4.3.2.2000': 'hnbnxfzrdifb1d5y',
#  'Mozilla/5.0 (Linux; Android 5.1; LENNY2 Build/LMY47I; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/67.0.3396.87 Mobile Safari/537.36': '384x81smgjs3kiga',
#  'Mozilla/5.0 (X11 Linux x86_64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/42.0.2311.135 Safari/537.36': 'vzmb1garqu4gc7l9',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-G925V Build/MMB29K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.68 Mobile Safari/537.36': '7z6pvzyfov6u5i5b',
#  'Opera/9.80 (J2ME/MIDP; Opera Mini/4.2.23453/64.228; U; ar) Presto/2.12.423 Version/12.16': 'vg8axurpn8wgwaqu',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; chromeframe/27.0.1453.110; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30; InfoPath.1; .NET CLR 1.1.4322; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; .NET4.0E; InfoPath.2; BOIE8;ENUSMSCOM)': 'g54cgvbt4nra5bhk',
#  'Mozilla/5.0 (Linux; Android 4.4.4; XT1028 Build/KXB21.14-L1.41) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.114 Mobile Safari/537.36': 'ku9fors14b4sdzbj',
#  'Mozilla/5.0 (Windows NT 5.1; rv:52.0) Gecko/20100101 Firefox/52.0 SeaMonkey/2.49.3': 'c3ajdm3kxk0lg9b5',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) QupZilla/2.0.0 Chrome/49.0.2623.111 Safari/537.36': 'si2xdwduw2sv3vhx',
#  'Mozilla/5.0 (Linux; Android 8.0.0; H3123 Build/50.1.A.5.59; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/69.0.3497.100 Mobile Safari/537.36 [FB_IAB/FB4A;FBAV/192.0.0.34.85;]': 'zeqghnq1vhrudo24',
#  'Mozilla/5.0 (compatible; MSIE or Firefox mutant; not on Windows server;) Daumoa/4.0': 'ealie6x1qycg0pps',
#  'Mozilla/5.0 (Linux; U; Android 4.0.4; vi-vn; F7HD Build/IMM76D) AppleWebKit/537.16 (KHTML, like Gecko) Version/4.0 Safari/537.16 Chrome/33.0.0.0': 'pztpyjzwps3ocjnk',
#  'Mozilla/5.0 (Windows NT 6.2; Win32; x32) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36': '30ld03930k96qyxi',
#  'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.0 Safari/537.4': 'acf9863qprsdwdx5',
# ...
#  'Mozilla/5.0 (Linux; U; Android 3.2.1; ru-ru; A500 Build/HTK55D) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0 Safari/534.13': '34pro7pmz7rlwi3r',
#  'Opera/9.80 (Android; Opera Mini/7.6.40234/65.257; U; id) Presto/2.12.423 Version/12.16': 'y5poov14eid1nio4',
#  'Mozilla/5.0 (Windows NT 5.1; rv:26.0) Gecko/20100101 Firefox/26.0 AlexaToolbar/amznf-3.0.20121129': 'wmntoknrnerw0xnh',
#  'Mozilla/5.0 (Linux; U; Android 2.3; en-us; SonyEricssonST25i Build/6.0.B.1.564) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1': 'j5q4eam7dpcuzqwi',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/601.4.4 (KHTML, like Gecko) Version/9.1.1 Safari/7046A194A': 'qig4d24ayr4s2j90',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; BTRS100194; SV1; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; McAfee; BOIE8;ENUSMSCOM)': '18f2ns6d5ez8af66',
#  'Opera/9.50 (Windows NT 5.1; U; pt-BR)': '5ejc6jqfzd424q8z',
#  'Mozilla/5.0 (Linux; Android 7.0; SAMSUNG-SM-G920A Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.111 Mobile Safari/537.36 EdgA/41.0.0.1662': 'fjspl4yh2bmero7i',
#  'BlackBerry8100/4.2.1 Profile/MIDP-2.0 Configuration/CLDC-1.1 VendorID/167': '754t41h2at2tkizi',
#  'Mozilla/5.0 (Linux; Android 4.4.2; T1-701u Build/HuaweiMediaPad; ro-ro) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.117 Safari/537.36 Puffin/7.1.2.18064AT': 'dnh5v2x5is19w9xw',
#  'Opera/9.80 (J2ME/MIDP; Opera Mini/5.1.21214/20.2489; U; en) Presto/2.5.25': 'vg55s7l2vdkr192q',
#  'Mozilla/5.0 (Macintosh; U; Intel Roccat/7.6 Mac OS X 10.6.8; en_GB) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/8.9 Safari/534.59.10': '70dfxoxsepcuqpcg',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.98 Safari/537.36 OPR/44.0.2510.857,gzip(gfe)': '2f2m90hy2gjqmk5z',
#  'Mozilla/5.0 (Linux; Android 5.1.1; Nexus 4 Build/LMY48B) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.91 Mobile Safari/537.36': 'm4bkbf8jy4lvlh1d',
#  'Mozilla/5.0 (Linux; Android 6.0; LG-K350 Build/MRA58K; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/70.0.3538.64 Mobile Safari/537.36 Instagram 68.0.0.11.99 Android (23/6.0; 320dpi; 720x1187; LGE/lge; LG-K350; mm1v; mm1v; es_CO; 128676146)': 'hew39ajrxtjxgaqs',
#  'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36': 'c0cilnplhphap53k',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1) ; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)': 'eu203wn0mbcnr4wv',
#  'Mozilla/5.0 (Linux; Ubuntu 14.04) AppleWebKit/537.36 Chromium/35.0.187.2 Safari/537.36': 'vhv6xijwr1c747le',
#  'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2366.355 Mobile Safari/537.36': 'mour6vs8mgt9osin',
#  'Mozilla/5.0 (X11; U; FreeBSD i386; ru; rv:1.8.1.10) Gecko/20080702 Firefox/3.0.1': '1xoimdu4rbovfk0l',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_0_3 like Mac OS X) AppleWebKit/602.1.50 (KHTML, like Gecko) GSA/34.1.167176684 Mobile/15A432 Safari/602.1': 'sa5keggd8zpinskj',
#  'Mozilla/5.0 (Linux; U; Android 6.0.1; D6503 Build/23.5.A.0.575; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/5.0 Mobile Safari/537.36': 'e1h2453s0dxhkq81',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 9.3 like Mac OS X; en_US) AppleWebKit/1 (KHTML, like Gecko) Mobile/1 Safari/1 iPhone/1 SellOnEtsy/2.31 rv:23100.39.0': 'qq0zphx7zxa819q4',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:15.0) Gecko/15.0 Firefox/15.0': 'oydmr0owrvvyd2on',
#  'Mozilla/5.0 (Linux; U; Android 4.1.2; pl-pl; SAMSUNG GT-I8190N/I8190NXXANR6 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30': 'luha8vh1pvqu3jb4',
#  'Mozilla/5.0 (Linux; Android 7.1.1; MI MAX 2 Build/NMF26F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.76 Mobile Safari/537.36': 'x37k68hnnrzhkjg2',
#  'Mozilla/4.0 (Windows XP 5.1) Java/1.5.0_10': 'd7clhujkwvbse7dj',
#  'Mozilla/5.0 (Linux; Android 7.0; SAMSUNG SM-G925S Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/7.4 Chrome/59.0.3071.125 Mobile Safari/537.36': 'lgjunwlsfbl3lyzi',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 11_0_1 like Mac OS X) AppleWebKit/604.1.34 (KHTML, like Gecko) CriOS/65.0.3325.152 Mobile/15A8391 Safari/604.1': 'zvr82r1r61rsmbeh',
#  'Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; WebView/3.0; NOKIA; Lumia 630) AppleWebKit/537.36 (KHTML, like Gecko) coc_coc_browser/56.100.29 Chrome/46.0.2486.0 Mobile Safari/537.36 Edge/13.10586': 'wcroztjul0yq2wni',
#  'Opera/9.80 (VRE; Opera Mini/4.2/37.8743; U; en) Presto/2.12.423 Version/12.16': 'now4b4vlgvd7d0gv',
#  'Mozilla/5.0 (X11; Linux x86_64; rv:2.0.0) Gecko/20100101 Firefox/4.0': 'cg6m9v69x47mjjmq',
#  'Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10.4; en-US; rv:1.9.2.28) Gecko/20120306 Firefox/3.6.28 InquisitiveMindsAddon': 'rrwm1nr0dafcv1it',
#  'Mozilla/5.0 (Linux; Android 5.1.1; SAMSUNG-SM-G750A Build/LMY47X; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/59.0.3071.125 Mobile Safari/537.36': 'qynlhdhk1nyu1asm',
#  'Mozilla/5.0 (Linux; Android 6.0.1; XT1254 Build/MCG24.251-5; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/52.0.2743.98 Mobile Safari/537.36': '5ybx1y6h6ei25h6o',
#  'Mozilla/5.0 (Linux; Android 7.0; M bot 51 Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Mobile Safari/537.36': 'my94eds2tsdt1v6t',
#  'Mozilla/5.0 (Linux; Android 4.4.4; Z826 Build/KTU84P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.93 Mobile Safari/537.36': 'btbx3p9iytfm0712',
#  'Mozilla/3.0 (MSIE 2.0; Windows NT 6.1; Trident/5.0)': 'ih5wbe0laajv0c42',
#  'Mozilla/5.0 (Linux; Android 7.1.1; SM-N950U Build/NMF26X) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.83 Mobile Safari/537.36': 'rflvivvjmcri139e',
#  'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.6262.367 Mobile Safari/537.36': 'bq2haoeyy5lvymqk',
#  'Mozilla/5.0 (Linux; Android 5.1.1; SAMSUNG-SM-G530A Build/LMY48B) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.98 Mobile Safari/537.36': 'gjfvohndppxe2485',
#  'Mozilla/5.0 (Linux; U; Android 2.3.5; es-us; MB855 Build/4.5.1A-1_SUN-254_13) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1': 'rvqvs7n0653aku5e',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Avant Browser; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2)': 'n2fcmuwqfrizfvl8',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; IPH 1.1.21.4019; McAfee; .NET4.0C; .NET4.0E)': 'deek9rrsgaph3dp1',
#  'Mozilla/4.0 (compatible; MSIE 8.0; AOL 9.6; AOLBuild 4340.168; Windows NT 6.0; Trident/4.0; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.5.30729; InfoPath.1; .NET4.0C; .NET CLR 3.0.30729)': '6c2vwp5uq8x21gxa',
#  'Opera/9.80 (Android; Opera Mini/20.0.2254/65.290; U; en) Presto/2.12.423 Version/12.16': 'xzyfsphprw2v0fj6',
#  'Mozilla/5.0 (Linux; Tizen 2.4; SAMSUNG SM-Z130H) AppleWebKit/537.3 (KHTML, like Gecko) Version/2.4 Mobile Safari/537.3': '7oa8lzj0otwm4hf9',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SM-G532M Build/MMB29T; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/67.0.3396.87 Mobile Safari/537.36 [FB_IAB/FB4A;FBAV/196.0.0.41.95;]': 'r9ffw9kcyk9getot',
#  'Mozilla/5.0 (Linux; Android 7.1.1; Moto E (4) Plus Build/NMA26.42-152; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/68.0.3440.91 Mobile Safari/537.36 Instagram 62.0.0.19.93 Android (25/7.1.1; 320dpi; 720x1280; motorola; Moto E (4) Plus; nicklaus_f; mt6735; es_CO; 123790716)': 'a6pkqk4ugnrmjz0u',
#  'Mozilla/5.0 (X11; U; Linux x86_64; en-gb) AppleWebKit/534.35 (KHTML, like Gecko)  Chrome/11.0.696.65 Safari/534.35 Puffin/2.9541AT': 'fmsrbjj21ft3uxp9',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 9_1 like Mac OS X) AppleWebKit/600.1.4 (KHTML, like Gecko) GSA/14.1.119979954 Mobile/13B143 Safari/600.1.4': 'a95izvfv5xbvevf3',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36 OPR/56.0.3051.104 (Edition Campaign ISYF)': 'ge6vsge72gxqh2w9',
#  'Mozilla/5.0 (Linux; Android 5.1.1; S905 Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.84 Safari/537.36': 'jdsxuq1olehnm8b9',
#  'Mozilla/5.0 (Linux; Android 6.0; CRO-L23 Build/HUAWEICRO-L23; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/68.0.3440.91 Mobile Safari/537.36': 'ybkl9d31yar566mr',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; DVD Owner)': '53r9n7bfcox3ljp7',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2812.0 Safari/537.36': 'xxd9sxxvrqb105i4',
#  'Opera/9.80 (Android; Opera Mini/7.6.40077/62.178; U; en) Presto/2.12.423 Version/12.16': 'wvtstme0j5uk8gro',
#  'Mozilla/5.0 (Linux; Android 5.0.2; SM-T355Y Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.95 Safari/537.36': 'gsk0ojr2als8tuj6',
#  'Opera/9.80 (Windows NT 6.1; Win64; x64; Edition Campaign 21) Presto/2.12.388 Version/12.12': 'k8w5yejsmpa791pe',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 UBrowser/6.1.2015.1007 Safari/537.36': 'nekoy33pbaxb80xv',
#  'Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2470.63 Safari/537.36': 'wbpknpqq57843w24',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; InfoPath.3; .NET4.0C; .NET4.0E; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727)': 'sbr4qtta7rhhwhta',
#  'Mozilla/5.0 (Linux; Android 5.0.1; LG-H422 Build/LRX21Y; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/49.0.2623.105 Mobile Safari/537.36': 'nhcv0jyekquhdi86',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2633.3 Safari/537.36': 'qmnag9p1wrjxewp7',
#  'Mozilla/5.0 (Linux; Android 5.1; HTC Desire 626s Build/LMY47O) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Mobile Safari/537.36': 'irjvof05py8y1995',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS6335; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 1.1.4322)': 'j3ev3xjkkmpy3m53',
#  'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.22 (KHTML, like Gecko) Chrome/25.0.1364.58 Safari/537.22': 'bn1ngrowgql0cwi0',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/17.17074': 'tfih0svpph7yzyob',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; BTRS123374; InfoPath.2; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET4.0C; OfficeLiveConnector.1.5; OfficeLivePatch.1.3)': 'pkcapu2652oiy0ff',
#  'Mozilla/5.0 (X11; Ubuntu; Linux; en-US) AppleWebKit/537.14 (KHTML, like Gecko) Version/5.0.4 Safari/537.14': 'irguoa7swytmfhtw',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36 OPR/39.0.2256.71 (Edition Campaign 69)': 'vjxbfx52on5pfb6x',
#  'Mozilla/5.0 (compatible; Konqueror/3.0-rc4; i686 Linux; 20020112)': 'xgmw2ewuzc6r3c56',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.162 Safari/535.19': 'k9mfe0laq5nxlpk9',
#  'Mozilla/5.0 (Linux; U; Android 7.0; en-US; Baccara Build/NRD90M) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2987.108 UCBrowser/12.9.7.1153 Mobile Safari/537.36': 'ycim8jms0rihb28d',
#  '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:56.0) Gecko/20100101 Firefox/56.0"': 'ryva3yzhgsrmyfa9',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-C7010 Build/MMB29M) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/4.2 Chrome/44.0.2403.133 Mobile Safari/537.36': 'wmj3qc50m0qrvhpe',
#  'Mozilla/5.0 (X11; CrOS x86_64 14.4.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2342.0 Safari/537.36': 'nm8x8xk0yte3sntx',
#  'Mozilla/5.0 (Linux; U; Android 4.0.3; hu-hu; ZP100 Build/IML74K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 MobilSafari/534.30': 'k3577tltlzsfswac',
#  'Mozilla/5.0 (Linux; Android 4.3; GT-I9505 Build/JSS15J) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.94 Mobile Safari/537.36': '0iojq758wnuivwtl',
#  'Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-G920R6 Build/MMB29K) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/4.0 Chrome/44.0.2403.133 Mobile Safari/537.36': 'kkqnc73plwr3sc0x',
#  'Opera/9.80 (Android; Opera Mini/22.0.2254/65.257; U; ar) Presto/2.12.423 Version/12.16': 'n8dlabaip88vnfa3',
#  'Mozilla/5.0 (Linux; Android 4.1.2; GT-N8000 Build/JZO54K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.84 Safari/537.36': 'epks8c15kdb7lkzc',
#  '"Mozilla/5.0 (X11; U; Linux i686; en-GB; rv:1.9.0.13) Gecko/2009080316 Ubuntu/8.04 (hardy) Firefox/3.0.13"': 'kf1jrs1xy3hshqpt',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; WOW64; FunWebProducts; SLCC1; .NET CLR 2.0.50727; .NET CLR 3.0.04506; Media Center PC 5.0)': 'ds90aza9ydngh97p',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; GTB7.5; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; AskTbORJ/5.15.25.36191)': 'ruly81r17foqo8wm',
#  '10.0.12) Gecko/20130108 Firefox/10.0.12 SeaMonkey/2.7.2" appcodename="" appname="" appversion="" platform="" vendor="" vendorsub=""/>': 'n8f94upyh4m09nh2',
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; SpamBlockerUtility 4.8.4; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; yie8; .NET4.0C; OfficeLiveConnector.1.5; OfficeLivePatch.1.3; yie8)': 'ip8zg3bay1o0m0ee',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12) AppleWebKit/602.3.12 (KHTML, like Gecko) Version/10.0 Safari/602.1.31': 'z4zrux8zwf1gm61j',
#  'Mozilla/5.0 (Linux; Android 4.4.4; TAQ-90042MK2 PO10373 Build/KTU84Q) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/33.0.0.0 Safari/537.36': 'hpov5362s4orbz2r',
#  'Opera/9.80 (J2ME/MIDP; Opera Mini/4.2.13337/83.102; U; en) Presto/2.12.423 Version/12.16': 'sson78tny45sz4ht',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) QtWebEngine/5.9.1 Chrome/56.0.2924.122 Safari/537.36': '0t89y98jwrrqjbqj',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 9_0_2 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13A452 Safari/601.1 PTST/401': 'x63g2sp16f8nop8x',
#  'Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.7; AOLBuild 4343.27; Windows NT 5.1; Trident/4.0; chromeframe/30.0.1599.69; Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1) ; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; McAfee; AskTB5.6)': 'untsd24vfcsg322y',
#  'Chrome/24.0.1295.0': '96eu1r98xvh74oc9',
#  'Mozilla/5.0 (Linux; Android 6.0.1; LG Optimus G pro/LG-E980) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883 Safari/9.1.2': 'bhufodch3j85nec8',
#  'Mozilla/5.0 (Linux; Android 5.1.1; KFFOWI Build/LMY49J; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/59.0.3071.125 Safari/537.36': '7a6n5dvln57g07ll',
#  'Mozilla/5.0 (Linux; Android 4.4.2; SM-T520 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.98 Safari/537.36': 'ezo1jja9ew7detht',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_2 like Mac OS X) AppleWebKit/537.51.1 (KHTML, like Gecko) CriOS/37.0.2062.52 Mobile/11A501 Safari/9537.53 (000207)': 'w5i7a15103pnahdu',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Win 9x 4.90; bgft)': 'zxv2e6v7urnb3gnf',
#  'Mozilla/5.0 (Linux; U; Android 7.0; en-US; FRD-AL00 Build/HUAWEIFRD-AL00) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2987.108 Quark/2.4.1.985 Mobile Safari/537.36': '2nqc3usorh2lfkhn',
#  'Mozilla/5.0 (Linux; Android 5.1.1; LGL51AL Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.93 Mobile Safari/537.36': '2567coacg4w1gnic',
#  ...}

# %%
df_test = df.copy()

# %%
df_test[df_test.session_id.isnull()]
# Out:
#                          ts           event_type session_id user_country  \
# 6367    01/03/2025 04:44:35  image_gallery_swipe       None           BE
# 10041   01/03/2025 06:38:35    search_impression       None           BE
# 11659   01/03/2025 09:40:39             map_zoom       None           ES
# 12735   01/03/2025 08:03:50  image_gallery_swipe       None           IT
# 26212   01/03/2025 06:24:07             map_move       None           PT
# ...                     ...                  ...        ...          ...
# 725792  01/03/2025 02:49:56  image_gallery_swipe       None           FR
# 727737  01/03/2025 03:21:23  image_gallery_swipe       None           ES
# 734356  01/03/2025 05:45:36             map_zoom       None           BE
# 749039  01/03/2025 03:58:09       apartment_view       None           CH
# 774757  01/03/2025 08:06:42             map_move       None           NL
#
#                                                user_agent page_country  \
# 6367    Mozilla/5.0 (68K; rv:8.0) Gecko/20100209 Firef...           ES
# 10041   UCWEB/2.0 (MIDP-2.0; U; Adr 6.0.1; id; SM-G532...           FR
# 11659   Opera/9.80 (J2ME/MIDP; Opera Mini/4.2.18149/37...           FR
# 12735   Mozilla/5.0 (Linux; Android 4.4.2; SM-T230 Bui...           ES
# 26212   Mozilla/5.0 (Linux; U; Android 4.3; en-in; ASU...           DE
# ...                                                   ...          ...
# 725792  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...           FR
# 727737  Opera/9.80 (Android; Opera Mini/7.6.40125/58.1...           FR
# 734356  Mozilla/5.0 (iPhone; CPU iPhone OS 11_2 like M...           DE
# 749039  Mozilla/5.0 (Linux; U; Android 4.1.2; en-au; G...           ES
# 774757  Mozilla/5.0 (Linux; Android 8.0.0; SM-G930T1 B...           ES
#
#                env
# 6367    production
# 10041   production
# 11659   production
# 12735   production
# 26212   production
# ...            ...
# 725792  production
# 727737  production
# 734356  production
# 749039  production
# 774757  production
#
# [83 rows x 7 columns]

# %%
def fill_session_id(row, dict):
    '''Function that recieves a df's row for None session_id and a dictionary as inputs and returns then new row with new session_id '''
    
    try:
        row['session_id']  = dict[ row['user_agent']]
        return row
    except Exception as e:
        print(f'Error while finding the new session_id: {e}')
        return np.nan

# %%
df = df.apply(lambda row: fill_session_id(row, session_id_user_agent_tuple_dict) if pd.isnull(row['session_id']) else row, axis=1)

# %%
df[df.session_id.isnull()]
# Out:
# Empty DataFrame
# Columns: [ts, event_type, session_id, user_country, user_agent, page_country, env]
# Index: []
